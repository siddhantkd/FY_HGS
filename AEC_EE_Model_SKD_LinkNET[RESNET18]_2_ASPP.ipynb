# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhantkd/FY_HGS/blob/main/AEC_EE_Model_SKD_LinkNET%5BRESNET18%5D_2_ASPP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **AEC _ EE - NET**
#
# 3. ResNet18_LINKNET with ASPP
#
# LINKNET _ ASPP
#
# BEST 30 epochs
#
# > F - 0.9801724121093752
#
# > IoU socre is:  0.8403416923529685

# %% [markdown]
# #IMPORT AND DRIVE LOAD

# %%
import cv2
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import keras
from tqdm import tqdm
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
# !nvidia-smi
# Out:
# Thu Dec 30 15:20:13 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8    28W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %% [markdown]
# #Data Loading

# %%
# !unzip '/content/drive/MyDrive/OUHANDS/OUHANDS_Siddhant.zip'

# %%
IMG_WIDTH = 320
IMG_HEIGHT = 320
IMG_CHANNELS = 3

# %%
path = "/content/OUHANDS_Siddhant/training/colour"
maskpath = "/content/OUHANDS_Siddhant/training/segmentation"

X_train = np.zeros((len(os.listdir(path)), IMG_HEIGHT, IMG_WIDTH,IMG_CHANNELS),dtype=np.uint8)
Y_train = np.zeros((len(os.listdir(maskpath)), IMG_HEIGHT, IMG_WIDTH,1))
print('creating input data')
n=0
for name in tqdm(os.listdir(path)):
    newpath = os.path.join(path,name)
    img=cv2.imread(newpath)
    img=cv2.resize(img,(IMG_WIDTH,IMG_HEIGHT))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    X_train[n]=img
    n+=1

m=0
for name in tqdm(os.listdir(maskpath)):
    newmaskpath = os.path.join(maskpath,name)
    mpg=cv2.imread(newmaskpath,0)
    mpg=cv2.resize(mpg,(IMG_WIDTH,IMG_HEIGHT))
    mpg=np.expand_dims(mpg,axis=-1)
    Y_train[m]=mpg/255
    m+=1
# Out:
# creating input data
# 100%|██████████| 2000/2000 [00:26<00:00, 75.34it/s]
# 100%|██████████| 2000/2000 [00:03<00:00, 588.52it/s]

# %%
plt.imshow(array_to_img(X_train[0]))

# %%
plt.imshow(array_to_img(Y_train[0]))

# %%
print(X_train.shape, Y_train.shape)
# Out:
# (2000, 320, 320, 3) (2000, 320, 320, 1)

# %% [markdown]
# # AEC_EE Model

# %%
# !pip install keras-pyramid-pooling-module

# %%
from tensorflow.keras.layers import Conv2D, Activation, BatchNormalization
from tensorflow.keras.layers import UpSampling2D, Input, Concatenate, Conv2DTranspose, Add, AveragePooling2D
from tensorflow.keras.models import Model

# %%
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import keras
from classification_models.keras import Classifiers

# %%
def ASPP(inputs):
    """ Image Pooling """
    shape = inputs.shape
    y1 = AveragePooling2D(pool_size=(shape[1], shape[2]))(inputs)
    y1 = Conv2D(512, 1, padding="same", use_bias=False)(y1)
    y1 = BatchNormalization()(y1)
    y1 = Activation("relu")(y1)
    y1 = UpSampling2D((shape[1], shape[2]), interpolation="bilinear")(y1)

    """ 1x1 conv """
    y2 = Conv2D(512, 1, padding="same", use_bias=False)(inputs)
    y2 = BatchNormalization()(y2)
    y2 = Activation("relu")(y2)

    """ 3x3 conv rate=6 """
    y3 = Conv2D(512, 3, padding="same", use_bias=False, dilation_rate=6)(inputs)
    y3 = BatchNormalization()(y3)
    y3 = Activation("relu")(y3)

    """ 3x3 conv rate=12 """
    y4 = Conv2D(512, 3, padding="same", use_bias=False, dilation_rate=12)(inputs)
    y4 = BatchNormalization()(y4)
    y4 = Activation("relu")(y4)

    """ 3x3 conv rate=18 """
    y5 = Conv2D(512, 3, padding="same", use_bias=False, dilation_rate=18)(inputs)
    y5 = BatchNormalization()(y5)
    y5 = Activation("relu")(y5)

    y = Concatenate()([y1, y2, y3, y4, y5])
    y = Conv2D(512, 1, padding="same", use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation("relu")(y)

    return y

# %%
"""Skip connections as per SM Models LINKnet with backbone Resnet 18"""

# LATEST MODEL - LINKNET only

def build_UNET_Resnet19():    
  ResNet18, preprocess_input = Classifiers.get('resnet18')
  model = ResNet18(input_shape=(320,320,3), include_top=False)
  model.load_weights("/content/drive/MyDrive/FY_HGS/AEC_EE_Unet_Resnet18_SKD/resnet18_imagenet_1000_no_top.h5")

  """ Skip Connections """

  s1 = model.get_layer("relu0").output                      ## (160, 160)
  s2 = model.get_layer("stage2_unit1_relu1").output         ## ( 80, 80)
  s3 = model.get_layer("stage3_unit1_relu1").output         ## (40, 40)
  s4 = model.get_layer("stage4_unit1_relu1").output         ## (20, 20)

  #print(s1.shape, s2.shape, s3.shape, s4.shape)

  """ Bridge """

  b1 = model.get_layer("relu1").output
  b1 = ASPP(b1)
  #print(b1.shape)

  """ Decoder """
  x = Conv2D(128, (3,3), kernel_initializer='he_normal', padding = 'same')(b1)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = tf.keras.layers.UpSampling2D( size=(2, 2), interpolation='nearest')(x)

  x = Conv2D(128, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Conv2D(256, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Add()([x, s4]) # ADD 1

  x = Conv2D(64, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = tf.keras.layers.UpSampling2D( size=(2, 2), interpolation='nearest')(x)

  x = Conv2D(64, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Conv2D(128, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Add()([x, s3]) # ADD 2

  x = Conv2D(32, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = tf.keras.layers.UpSampling2D( size=(2, 2), interpolation='nearest')(x)

  x = Conv2D(32, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Conv2D(64, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Add()([x, s2]) # ADD 3

  x = Conv2D(16, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = tf.keras.layers.UpSampling2D( size=(2, 2), interpolation='nearest')(x)

  x = Conv2D(16, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Conv2D(64, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Add()([x, s1]) # ADD 4

  x = Conv2D(16, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = tf.keras.layers.UpSampling2D( size=(2, 2), interpolation='nearest')(x)

  x = Conv2D(16, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Conv2D(16, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  outputs = Conv2D(1, 1, kernel_initializer='he_normal',padding="same")(x)
  outputs = Activation('sigmoid')(outputs)

  model = keras.models.Model(inputs=[model.input], outputs=[outputs])  

  #print(model.summary())

  return model

# %%
#Sanity check, view few mages
import random
import numpy as np
image_number = random.randint(0, len(X_train))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(X_train[image_number])
plt.subplot(122)
plt.imshow(array_to_img(Y_train[image_number]), cmap='gray')
plt.show()

# %%
model = build_UNET_Resnet19()
print(model.summary())
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  data (InputLayer)              [(None, 320, 320, 3  0           []
#                                 )]
#
#  bn_data (BatchNormalization)   (None, 320, 320, 3)  9           ['data[0][0]']
#
#  zero_padding2d_18 (ZeroPadding  (None, 326, 326, 3)  0          ['bn_data[0][0]']
#  2D)
#
#  conv0 (Conv2D)                 (None, 160, 160, 64  9408        ['zero_padding2d_18[0][0]']
#                                 )
#
#  bn0 (BatchNormalization)       (None, 160, 160, 64  256         ['conv0[0][0]']
#                                 )
#
#  relu0 (Activation)             (None, 160, 160, 64  0           ['bn0[0][0]']
#                                 )
#
#  zero_padding2d_19 (ZeroPadding  (None, 162, 162, 64  0          ['relu0[0][0]']
#  2D)                            )
#
#  pooling0 (MaxPooling2D)        (None, 80, 80, 64)   0           ['zero_padding2d_19[0][0]']
#
#  stage1_unit1_bn1 (BatchNormali  (None, 80, 80, 64)  256         ['pooling0[0][0]']
#  zation)
#
#  stage1_unit1_relu1 (Activation  (None, 80, 80, 64)  0           ['stage1_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_20 (ZeroPadding  (None, 82, 82, 64)  0           ['stage1_unit1_relu1[0][0]']
#  2D)
#
#  stage1_unit1_conv1 (Conv2D)    (None, 80, 80, 64)   36864       ['zero_padding2d_20[0][0]']
#
#  stage1_unit1_bn2 (BatchNormali  (None, 80, 80, 64)  256         ['stage1_unit1_conv1[0][0]']
#  zation)
#
#  stage1_unit1_relu2 (Activation  (None, 80, 80, 64)  0           ['stage1_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_21 (ZeroPadding  (None, 82, 82, 64)  0           ['stage1_unit1_relu2[0][0]']
#  2D)
#
#  stage1_unit1_conv2 (Conv2D)    (None, 80, 80, 64)   36864       ['zero_padding2d_21[0][0]']
#
#  stage1_unit1_sc (Conv2D)       (None, 80, 80, 64)   4096        ['stage1_unit1_relu1[0][0]']
#
#  add_8 (Add)                    (None, 80, 80, 64)   0           ['stage1_unit1_conv2[0][0]',
#                                                                   'stage1_unit1_sc[0][0]']
#
#  stage1_unit2_bn1 (BatchNormali  (None, 80, 80, 64)  256         ['add_8[0][0]']
#  zation)
#
#  stage1_unit2_relu1 (Activation  (None, 80, 80, 64)  0           ['stage1_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_22 (ZeroPadding  (None, 82, 82, 64)  0           ['stage1_unit2_relu1[0][0]']
#  2D)
#
#  stage1_unit2_conv1 (Conv2D)    (None, 80, 80, 64)   36864       ['zero_padding2d_22[0][0]']
#
#  stage1_unit2_bn2 (BatchNormali  (None, 80, 80, 64)  256         ['stage1_unit2_conv1[0][0]']
#  zation)
#
#  stage1_unit2_relu2 (Activation  (None, 80, 80, 64)  0           ['stage1_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_23 (ZeroPadding  (None, 82, 82, 64)  0           ['stage1_unit2_relu2[0][0]']
#  2D)
#
#  stage1_unit2_conv2 (Conv2D)    (None, 80, 80, 64)   36864       ['zero_padding2d_23[0][0]']
#
#  add_9 (Add)                    (None, 80, 80, 64)   0           ['stage1_unit2_conv2[0][0]',
#                                                                   'add_8[0][0]']
#
#  stage2_unit1_bn1 (BatchNormali  (None, 80, 80, 64)  256         ['add_9[0][0]']
#  zation)
#
#  stage2_unit1_relu1 (Activation  (None, 80, 80, 64)  0           ['stage2_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_24 (ZeroPadding  (None, 82, 82, 64)  0           ['stage2_unit1_relu1[0][0]']
#  2D)
#
#  stage2_unit1_conv1 (Conv2D)    (None, 40, 40, 128)  73728       ['zero_padding2d_24[0][0]']
#
#  stage2_unit1_bn2 (BatchNormali  (None, 40, 40, 128)  512        ['stage2_unit1_conv1[0][0]']
#  zation)
#
#  stage2_unit1_relu2 (Activation  (None, 40, 40, 128)  0          ['stage2_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_25 (ZeroPadding  (None, 42, 42, 128)  0          ['stage2_unit1_relu2[0][0]']
#  2D)
#
#  stage2_unit1_conv2 (Conv2D)    (None, 40, 40, 128)  147456      ['zero_padding2d_25[0][0]']
#
#  stage2_unit1_sc (Conv2D)       (None, 40, 40, 128)  8192        ['stage2_unit1_relu1[0][0]']
#
#  add_10 (Add)                   (None, 40, 40, 128)  0           ['stage2_unit1_conv2[0][0]',
#                                                                   'stage2_unit1_sc[0][0]']
#
#  stage2_unit2_bn1 (BatchNormali  (None, 40, 40, 128)  512        ['add_10[0][0]']
#  zation)
#
#  stage2_unit2_relu1 (Activation  (None, 40, 40, 128)  0          ['stage2_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_26 (ZeroPadding  (None, 42, 42, 128)  0          ['stage2_unit2_relu1[0][0]']
#  2D)
#
#  stage2_unit2_conv1 (Conv2D)    (None, 40, 40, 128)  147456      ['zero_padding2d_26[0][0]']
#
#  stage2_unit2_bn2 (BatchNormali  (None, 40, 40, 128)  512        ['stage2_unit2_conv1[0][0]']
#  zation)
#
#  stage2_unit2_relu2 (Activation  (None, 40, 40, 128)  0          ['stage2_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_27 (ZeroPadding  (None, 42, 42, 128)  0          ['stage2_unit2_relu2[0][0]']
#  2D)
#
#  stage2_unit2_conv2 (Conv2D)    (None, 40, 40, 128)  147456      ['zero_padding2d_27[0][0]']
#
#  add_11 (Add)                   (None, 40, 40, 128)  0           ['stage2_unit2_conv2[0][0]',
#                                                                   'add_10[0][0]']
#
#  stage3_unit1_bn1 (BatchNormali  (None, 40, 40, 128)  512        ['add_11[0][0]']
#  zation)
#
#  stage3_unit1_relu1 (Activation  (None, 40, 40, 128)  0          ['stage3_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_28 (ZeroPadding  (None, 42, 42, 128)  0          ['stage3_unit1_relu1[0][0]']
#  2D)
#
#  stage3_unit1_conv1 (Conv2D)    (None, 20, 20, 256)  294912      ['zero_padding2d_28[0][0]']
#
#  stage3_unit1_bn2 (BatchNormali  (None, 20, 20, 256)  1024       ['stage3_unit1_conv1[0][0]']
#  zation)
#
#  stage3_unit1_relu2 (Activation  (None, 20, 20, 256)  0          ['stage3_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_29 (ZeroPadding  (None, 22, 22, 256)  0          ['stage3_unit1_relu2[0][0]']
#  2D)
#
#  stage3_unit1_conv2 (Conv2D)    (None, 20, 20, 256)  589824      ['zero_padding2d_29[0][0]']
#
#  stage3_unit1_sc (Conv2D)       (None, 20, 20, 256)  32768       ['stage3_unit1_relu1[0][0]']
#
#  add_12 (Add)                   (None, 20, 20, 256)  0           ['stage3_unit1_conv2[0][0]',
#                                                                   'stage3_unit1_sc[0][0]']
#
#  stage3_unit2_bn1 (BatchNormali  (None, 20, 20, 256)  1024       ['add_12[0][0]']
#  zation)
#
#  stage3_unit2_relu1 (Activation  (None, 20, 20, 256)  0          ['stage3_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_30 (ZeroPadding  (None, 22, 22, 256)  0          ['stage3_unit2_relu1[0][0]']
#  2D)
#
#  stage3_unit2_conv1 (Conv2D)    (None, 20, 20, 256)  589824      ['zero_padding2d_30[0][0]']
#
#  stage3_unit2_bn2 (BatchNormali  (None, 20, 20, 256)  1024       ['stage3_unit2_conv1[0][0]']
#  zation)
#
#  stage3_unit2_relu2 (Activation  (None, 20, 20, 256)  0          ['stage3_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_31 (ZeroPadding  (None, 22, 22, 256)  0          ['stage3_unit2_relu2[0][0]']
#  2D)
#
#  stage3_unit2_conv2 (Conv2D)    (None, 20, 20, 256)  589824      ['zero_padding2d_31[0][0]']
#
#  add_13 (Add)                   (None, 20, 20, 256)  0           ['stage3_unit2_conv2[0][0]',
#                                                                   'add_12[0][0]']
#
#  stage4_unit1_bn1 (BatchNormali  (None, 20, 20, 256)  1024       ['add_13[0][0]']
#  zation)
#
#  stage4_unit1_relu1 (Activation  (None, 20, 20, 256)  0          ['stage4_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_32 (ZeroPadding  (None, 22, 22, 256)  0          ['stage4_unit1_relu1[0][0]']
#  2D)
#
#  stage4_unit1_conv1 (Conv2D)    (None, 10, 10, 512)  1179648     ['zero_padding2d_32[0][0]']
#
#  stage4_unit1_bn2 (BatchNormali  (None, 10, 10, 512)  2048       ['stage4_unit1_conv1[0][0]']
#  zation)
#
#  stage4_unit1_relu2 (Activation  (None, 10, 10, 512)  0          ['stage4_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_33 (ZeroPadding  (None, 12, 12, 512)  0          ['stage4_unit1_relu2[0][0]']
#  2D)
#
#  stage4_unit1_conv2 (Conv2D)    (None, 10, 10, 512)  2359296     ['zero_padding2d_33[0][0]']
#
#  stage4_unit1_sc (Conv2D)       (None, 10, 10, 512)  131072      ['stage4_unit1_relu1[0][0]']
#
#  add_14 (Add)                   (None, 10, 10, 512)  0           ['stage4_unit1_conv2[0][0]',
#                                                                   'stage4_unit1_sc[0][0]']
#
#  stage4_unit2_bn1 (BatchNormali  (None, 10, 10, 512)  2048       ['add_14[0][0]']
#  zation)
#
#  stage4_unit2_relu1 (Activation  (None, 10, 10, 512)  0          ['stage4_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_34 (ZeroPadding  (None, 12, 12, 512)  0          ['stage4_unit2_relu1[0][0]']
#  2D)
#
#  stage4_unit2_conv1 (Conv2D)    (None, 10, 10, 512)  2359296     ['zero_padding2d_34[0][0]']
#
#  stage4_unit2_bn2 (BatchNormali  (None, 10, 10, 512)  2048       ['stage4_unit2_conv1[0][0]']
#  zation)
#
#  stage4_unit2_relu2 (Activation  (None, 10, 10, 512)  0          ['stage4_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_35 (ZeroPadding  (None, 12, 12, 512)  0          ['stage4_unit2_relu2[0][0]']
#  2D)
#
#  stage4_unit2_conv2 (Conv2D)    (None, 10, 10, 512)  2359296     ['zero_padding2d_35[0][0]']
#
#  add_15 (Add)                   (None, 10, 10, 512)  0           ['stage4_unit2_conv2[0][0]',
#                                                                   'add_14[0][0]']
#
#  bn1 (BatchNormalization)       (None, 10, 10, 512)  2048        ['add_15[0][0]']
#
#  relu1 (Activation)             (None, 10, 10, 512)  0           ['bn1[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 1, 1, 512)   0           ['relu1[0][0]']
#  oling2D)
#
#  conv2d_7 (Conv2D)              (None, 1, 1, 512)    262144      ['average_pooling2d_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 1, 1, 512)   2048        ['conv2d_7[0][0]']
#  rmalization)
#
#  conv2d_8 (Conv2D)              (None, 10, 10, 512)  262144      ['relu1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 10, 10, 512)  2359296     ['relu1[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 10, 10, 512)  2359296     ['relu1[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 10, 10, 512)  2359296     ['relu1[0][0]']
#
#  activation_6 (Activation)      (None, 1, 1, 512)    0           ['batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 10, 10, 512)  2048       ['conv2d_8[0][0]']
#  rmalization)
#
#  batch_normalization_8 (BatchNo  (None, 10, 10, 512)  2048       ['conv2d_9[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 10, 10, 512)  2048       ['conv2d_10[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 10, 10, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 10, 10, 512)  0          ['activation_6[0][0]']
#
#  activation_7 (Activation)      (None, 10, 10, 512)  0           ['batch_normalization_7[0][0]']
#
#  activation_8 (Activation)      (None, 10, 10, 512)  0           ['batch_normalization_8[0][0]']
#
#  activation_9 (Activation)      (None, 10, 10, 512)  0           ['batch_normalization_9[0][0]']
#
#  activation_10 (Activation)     (None, 10, 10, 512)  0           ['batch_normalization_10[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 10, 10, 2560  0           ['up_sampling2d_1[0][0]',
#                                 )                                 'activation_7[0][0]',
#                                                                   'activation_8[0][0]',
#                                                                   'activation_9[0][0]',
#                                                                   'activation_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 10, 10, 512)  1310720     ['concatenate_1[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 10, 10, 512)  2048       ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 10, 10, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 10, 10, 128)  589952      ['activation_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 10, 10, 128)  512        ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 10, 10, 128)  0           ['batch_normalization_12[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 20, 20, 128)  0          ['activation_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 20, 20, 128)  147584      ['up_sampling2d_2[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 20, 20, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 20, 20, 128)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 20, 20, 256)  295168      ['activation_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 20, 20, 256)  1024       ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 20, 20, 256)  0           ['batch_normalization_14[0][0]']
#
#  add_16 (Add)                   (None, 20, 20, 256)  0           ['activation_14[0][0]',
#                                                                   'stage4_unit1_relu1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 20, 20, 64)   147520      ['add_16[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 20, 20, 64)  256         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 20, 20, 64)   0           ['batch_normalization_15[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 40, 40, 64)  0           ['activation_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 40, 40, 64)   36928       ['up_sampling2d_3[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 40, 40, 64)  256         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 40, 40, 64)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 40, 40, 128)  73856       ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 40, 40, 128)  512        ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 40, 40, 128)  0           ['batch_normalization_17[0][0]']
#
#  add_17 (Add)                   (None, 40, 40, 128)  0           ['activation_17[0][0]',
#                                                                   'stage3_unit1_relu1[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 40, 40, 32)   36896       ['add_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 40, 40, 32)  128         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 40, 40, 32)   0           ['batch_normalization_18[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 80, 80, 32)  0           ['activation_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 80, 80, 32)   9248        ['up_sampling2d_4[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 80, 80, 32)  128         ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 80, 80, 32)   0           ['batch_normalization_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 80, 80, 64)   18496       ['activation_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 80, 80, 64)  256         ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 80, 80, 64)   0           ['batch_normalization_20[0][0]']
#
#  add_18 (Add)                   (None, 80, 80, 64)   0           ['activation_20[0][0]',
#                                                                   'stage2_unit1_relu1[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 80, 80, 16)   9232        ['add_18[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 80, 80, 16)  64          ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 80, 80, 16)   0           ['batch_normalization_21[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 160, 160, 16  0          ['activation_21[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 160, 160, 16  2320        ['up_sampling2d_5[0][0]']
#                                 )
#
#  batch_normalization_22 (BatchN  (None, 160, 160, 16  64         ['conv2d_23[0][0]']
#  ormalization)                  )
#
#  activation_22 (Activation)     (None, 160, 160, 16  0           ['batch_normalization_22[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 160, 160, 64  9280        ['activation_22[0][0]']
#                                 )
#
#  batch_normalization_23 (BatchN  (None, 160, 160, 64  256        ['conv2d_24[0][0]']
#  ormalization)                  )
#
#  activation_23 (Activation)     (None, 160, 160, 64  0           ['batch_normalization_23[0][0]']
#                                 )
#
#  add_19 (Add)                   (None, 160, 160, 64  0           ['activation_23[0][0]',
#                                 )                                 'relu0[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 160, 160, 16  9232        ['add_19[0][0]']
#                                 )
#
#  batch_normalization_24 (BatchN  (None, 160, 160, 16  64         ['conv2d_25[0][0]']
#  ormalization)                  )
#
#  activation_24 (Activation)     (None, 160, 160, 16  0           ['batch_normalization_24[0][0]']
#                                 )
#
#  up_sampling2d_6 (UpSampling2D)  (None, 320, 320, 16  0          ['activation_24[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 320, 320, 16  2320        ['up_sampling2d_6[0][0]']
#                                 )
#
#  batch_normalization_25 (BatchN  (None, 320, 320, 16  64         ['conv2d_26[0][0]']
#  ormalization)                  )
#
#  activation_25 (Activation)     (None, 320, 320, 16  0           ['batch_normalization_25[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 320, 320, 16  2320        ['activation_25[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 320, 320, 16  64         ['conv2d_27[0][0]']
#  ormalization)                  )
#
#  activation_26 (Activation)     (None, 320, 320, 16  0           ['batch_normalization_26[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 320, 320, 1)  17          ['activation_26[0][0]']
#
#  activation_27 (Activation)     (None, 320, 320, 1)  0           ['conv2d_28[0][0]']
#
# ==================================================================================================
# Total params: 21,506,602
# Trainable params: 21,490,436
# Non-trainable params: 16,166
# __________________________________________________________________________________________________
# None

# %%
from tensorflow.keras.optimizers import Adam

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
model.compile(loss=dice_loss, optimizer=Adam(1e-4), metrics=[dice_coef, iou])

# %% [markdown]
# # MODEL TRAINING

# %% [markdown]
# ##20 epochs

# %%
#Model Checkpoint
checkpoint_path_segmentUNET = "/content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/cp.ckpt"
model_checkpoint_segmentUNET = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path_segmentUNET,
                                                 save_weights_only=True,
                                                  monitor='val_loss',save_best_only=True,
                                                 verbose=1)

# %%
history = model.fit(X_train,Y_train,validation_split = 0.1,batch_size=8,epochs=20, callbacks=[model_checkpoint_segmentUNET])
# Out:
# Epoch 1/20
# 225/225 [==============================] - ETA: 0s - loss: 0.6445 - dice_coef: 0.3555 - iou: 0.2182
# Epoch 00001: val_loss improved from inf to 0.62246, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/cp.ckpt
# 225/225 [==============================] - 134s 505ms/step - loss: 0.6445 - dice_coef: 0.3555 - iou: 0.2182 - val_loss: 0.6225 - val_dice_coef: 0.3775 - val_iou: 0.2337
# Epoch 2/20
# 225/225 [==============================] - ETA: 0s - loss: 0.5900 - dice_coef: 0.4100 - iou: 0.2592
# Epoch 00002: val_loss improved from 0.62246 to 0.57333, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/cp.ckpt
# 225/225 [==============================] - 112s 498ms/step - loss: 0.5900 - dice_coef: 0.4100 - iou: 0.2592 - val_loss: 0.5733 - val_dice_coef: 0.4267 - val_iou: 0.2724
# Epoch 3/20
# 225/225 [==============================] - ETA: 0s - loss: 0.5573 - dice_coef: 0.4427 - iou: 0.2858
# Epoch 00003: val_loss improved from 0.57333 to 0.54220, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/cp.ckpt
# 225/225 [==============================] - 112s 498ms/step - loss: 0.5573 - dice_coef: 0.4427 - iou: 0.2858 - val_loss: 0.5422 - val_dice_coef: 0.4578 - val_iou: 0.2982
# Epoch 4/20
# 225/225 [==============================] - ETA: 0s - loss: 0.5233 - dice_coef: 0.4767 - iou: 0.3146
# Epoch 00004: val_loss improved from 0.54220 to 0.50570, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/cp.ckpt
# 225/225 [==============================] - 112s 498ms/step - loss: 0.5233 - dice_coef: 0.4767 - iou: 0.3146 - val_loss: 0.5057 - val_dice_coef: 0.4943 - val_iou: 0.3297
# Epoch 5/20
# 225/225 [==============================] - ETA: 0s - loss: 0.4862 - dice_coef: 0.5138 - iou: 0.3476
# Epoch 00005: val_loss improved from 0.50570 to 0.46578, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/cp.ckpt
# 225/225 [==============================] - 112s 497ms/step - loss: 0.4862 - dice_coef: 0.5138 - iou: 0.3476 - val_loss: 0.4658 - val_dice_coef: 0.5342 - val_iou: 0.3660
# Epoch 6/20
# 225/225 [==============================] - ETA: 0s - loss: 0.4458 - dice_coef: 0.5542 - iou: 0.3856
# Epoch 00006: val_loss improved from 0.46578 to 0.42357, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/cp.ckpt
# 225/225 [==============================] - 112s 496ms/step - loss: 0.4458 - dice_coef: 0.5542 - iou: 0.3856 - val_loss: 0.4236 - val_dice_coef: 0.5764 - val_iou: 0.4064
# Epoch 7/20
# 225/225 [==============================] - ETA: 0s - loss: 0.4021 - dice_coef: 0.5979 - iou: 0.4285
# Epoch 00007: val_loss improved from 0.42357 to 0.38023, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/cp.ckpt
# 225/225 [==============================] - 112s 497ms/step - loss: 0.4021 - dice_coef: 0.5979 - iou: 0.4285 - val_loss: 0.3802 - val_dice_coef: 0.6198 - val_iou: 0.4505
# Epoch 8/20
# 225/225 [==============================] - ETA: 0s - loss: 0.3595 - dice_coef: 0.6405 - iou: 0.4734
# Epoch 00008: val_loss improved from 0.38023 to 0.33891, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/cp.ckpt
# 225/225 [==============================] - 112s 497ms/step - loss: 0.3595 - dice_coef: 0.6405 - iou: 0.4734 - val_loss: 0.3389 - val_dice_coef: 0.6611 - val_iou: 0.4952
# Epoch 9/20
# 225/225 [==============================] - ETA: 0s - loss: 0.3219 - dice_coef: 0.6781 - iou: 0.5157
# Epoch 00009: val_loss improved from 0.33891 to 0.30261, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/cp.ckpt
# 225/225 [==============================] - 112s 497ms/step - loss: 0.3219 - dice_coef: 0.6781 - iou: 0.5157 - val_loss: 0.3026 - val_dice_coef: 0.6974 - val_iou: 0.5368
# Epoch 10/20
# 225/225 [==============================] - ETA: 0s - loss: 0.2795 - dice_coef: 0.7205 - iou: 0.5653
# Epoch 00010: val_loss improved from 0.30261 to 0.26937, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/cp.ckpt
# 225/225 [==============================] - 112s 496ms/step - loss: 0.2795 - dice_coef: 0.7205 - iou: 0.5653 - val_loss: 0.2694 - val_dice_coef: 0.7306 - val_iou: 0.5769
# Epoch 11/20
# 225/225 [==============================] - ETA: 0s - loss: 0.2361 - dice_coef: 0.7639 - iou: 0.6199
# Epoch 00011: val_loss improved from 0.26937 to 0.23849, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/cp.ckpt
# 225/225 [==============================] - 112s 496ms/step - loss: 0.2361 - dice_coef: 0.7639 - iou: 0.6199 - val_loss: 0.2385 - val_dice_coef: 0.7615 - val_iou: 0.6160
# Epoch 12/20
# 225/225 [==============================] - ETA: 0s - loss: 0.2032 - dice_coef: 0.7968 - iou: 0.6641
# Epoch 00012: val_loss improved from 0.23849 to 0.20212, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/cp.ckpt
# 225/225 [==============================] - 112s 498ms/step - loss: 0.2032 - dice_coef: 0.7968 - iou: 0.6641 - val_loss: 0.2021 - val_dice_coef: 0.7979 - val_iou: 0.6647
# Epoch 13/20
# 225/225 [==============================] - ETA: 0s - loss: 0.1750 - dice_coef: 0.8250 - iou: 0.7038
# Epoch 00013: val_loss improved from 0.20212 to 0.17728, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/cp.ckpt
# 225/225 [==============================] - 112s 497ms/step - loss: 0.1750 - dice_coef: 0.8250 - iou: 0.7038 - val_loss: 0.1773 - val_dice_coef: 0.8227 - val_iou: 0.6996
# Epoch 14/20
# 225/225 [==============================] - ETA: 0s - loss: 0.1507 - dice_coef: 0.8493 - iou: 0.7393
# Epoch 00014: val_loss improved from 0.17728 to 0.15824, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/cp.ckpt
# 225/225 [==============================] - 112s 497ms/step - loss: 0.1507 - dice_coef: 0.8493 - iou: 0.7393 - val_loss: 0.1582 - val_dice_coef: 0.8418 - val_iou: 0.7275
# Epoch 15/20
# 225/225 [==============================] - ETA: 0s - loss: 0.1313 - dice_coef: 0.8687 - iou: 0.7689
# Epoch 00015: val_loss improved from 0.15824 to 0.13909, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/cp.ckpt
# 225/225 [==============================] - 112s 496ms/step - loss: 0.1313 - dice_coef: 0.8687 - iou: 0.7689 - val_loss: 0.1391 - val_dice_coef: 0.8609 - val_iou: 0.7563
# Epoch 16/20
# 225/225 [==============================] - ETA: 0s - loss: 0.1154 - dice_coef: 0.8846 - iou: 0.7940
# Epoch 00016: val_loss improved from 0.13909 to 0.12425, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/cp.ckpt
# 225/225 [==============================] - 112s 496ms/step - loss: 0.1154 - dice_coef: 0.8846 - iou: 0.7940 - val_loss: 0.1242 - val_dice_coef: 0.8758 - val_iou: 0.7794
# Epoch 17/20
# 225/225 [==============================] - ETA: 0s - loss: 0.1015 - dice_coef: 0.8985 - iou: 0.8164
# Epoch 00017: val_loss improved from 0.12425 to 0.11442, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/cp.ckpt
# 225/225 [==============================] - 112s 497ms/step - loss: 0.1015 - dice_coef: 0.8985 - iou: 0.8164 - val_loss: 0.1144 - val_dice_coef: 0.8856 - val_iou: 0.7951
# Epoch 18/20
# 225/225 [==============================] - ETA: 0s - loss: 0.0895 - dice_coef: 0.9105 - iou: 0.8361
# Epoch 00018: val_loss improved from 0.11442 to 0.10242, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/cp.ckpt
# 225/225 [==============================] - 112s 496ms/step - loss: 0.0895 - dice_coef: 0.9105 - iou: 0.8361 - val_loss: 0.1024 - val_dice_coef: 0.8976 - val_iou: 0.8145
# Epoch 19/20
# 225/225 [==============================] - ETA: 0s - loss: 0.0800 - dice_coef: 0.9200 - iou: 0.8522
# Epoch 00019: val_loss improved from 0.10242 to 0.09600, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/cp.ckpt
# 225/225 [==============================] - 112s 500ms/step - loss: 0.0800 - dice_coef: 0.9200 - iou: 0.8522 - val_loss: 0.0960 - val_dice_coef: 0.9040 - val_iou: 0.8251
# Epoch 20/20
# 225/225 [==============================] - ETA: 0s - loss: 0.0715 - dice_coef: 0.9285 - iou: 0.8669
# Epoch 00020: val_loss improved from 0.09600 to 0.08915, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/cp.ckpt
# 225/225 [==============================] - 112s 497ms/step - loss: 0.0715 - dice_coef: 0.9285 - iou: 0.8669 - val_loss: 0.0892 - val_dice_coef: 0.9108 - val_iou: 0.8365

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.figure()
N = 20
plt.plot(np.arange(0,N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0,N), history.history["val_loss"], label = "val_loss")
plt.plot(np.arange(0,N), history.history["iou"], label = "train_iou_score")
plt.plot(np.arange(0,N), history.history["val_iou"], label = "val_iou_score")
plt.legend(loc="center right")
plt.title("Training Loss and IOU plot")
plt.xlabel("Epoch")
plt.savefig('UNET_Traininerrorplot_SEGMENTATION_RGB.png')

# %%
plt.plot(np.arange(0,N), history.history["val_loss"], label = "val_loss")
plt.title("Validation loss plot")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.savefig('UNET_ValLossPlot_SEGMENTATION_V1.2.png')

# %%
plt.plot(np.arange(0,N), history.history["loss"], label = "val_loss")
plt.title("Training loss plot")
plt.xlabel("Epoch")
plt.ylabel("Training Loss")
plt.savefig('UNET_TrainLossPlot_SEGMENTATION_V1.2.png')

# %% [markdown]
# ##30 Epochs

# %%
checkpoint_path_segmentUNET = ""
model.load_weights(checkpoint_path_segmentUNET)

# %%
checkpoint_path_segmentUNET = "/content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/30/cp.ckpt"
model_checkpoint_segmentUNET = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path_segmentUNET,
                                                 save_weights_only=True,
                                                  monitor='val_loss',save_best_only=True,
                                                 verbose=1)

# %%
h2 =  model.fit(X_train,Y_train,validation_split = 0.1,batch_size=8,epochs=10,callbacks=[model_checkpoint_segmentUNET])
# Out:
# Epoch 1/10
# 225/225 [==============================] - ETA: 0s - loss: 0.0649 - dice_coef: 0.9351 - iou: 0.8783
# Epoch 00001: val_loss improved from inf to 0.08363, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/30/cp.ckpt
# 225/225 [==============================] - 112s 497ms/step - loss: 0.0649 - dice_coef: 0.9351 - iou: 0.8783 - val_loss: 0.0836 - val_dice_coef: 0.9164 - val_iou: 0.8459
# Epoch 2/10
# 225/225 [==============================] - ETA: 0s - loss: 0.0600 - dice_coef: 0.9400 - iou: 0.8871
# Epoch 00002: val_loss improved from 0.08363 to 0.07885, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/30/cp.ckpt
# 225/225 [==============================] - 112s 497ms/step - loss: 0.0600 - dice_coef: 0.9400 - iou: 0.8871 - val_loss: 0.0788 - val_dice_coef: 0.9211 - val_iou: 0.8540
# Epoch 3/10
# 225/225 [==============================] - ETA: 0s - loss: 0.0544 - dice_coef: 0.9456 - iou: 0.8970
# Epoch 00003: val_loss improved from 0.07885 to 0.07408, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/30/cp.ckpt
# 225/225 [==============================] - 112s 499ms/step - loss: 0.0544 - dice_coef: 0.9456 - iou: 0.8970 - val_loss: 0.0741 - val_dice_coef: 0.9259 - val_iou: 0.8622
# Epoch 4/10
# 225/225 [==============================] - ETA: 0s - loss: 0.0504 - dice_coef: 0.9496 - iou: 0.9043
# Epoch 00004: val_loss improved from 0.07408 to 0.07031, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/30/cp.ckpt
# 225/225 [==============================] - 113s 501ms/step - loss: 0.0504 - dice_coef: 0.9496 - iou: 0.9043 - val_loss: 0.0703 - val_dice_coef: 0.9297 - val_iou: 0.8688
# Epoch 5/10
# 225/225 [==============================] - ETA: 0s - loss: 0.0466 - dice_coef: 0.9534 - iou: 0.9112
# Epoch 00005: val_loss improved from 0.07031 to 0.06893, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/30/cp.ckpt
# 225/225 [==============================] - 113s 501ms/step - loss: 0.0466 - dice_coef: 0.9534 - iou: 0.9112 - val_loss: 0.0689 - val_dice_coef: 0.9311 - val_iou: 0.8712
# Epoch 6/10
# 225/225 [==============================] - ETA: 0s - loss: 0.0430 - dice_coef: 0.9570 - iou: 0.9176
# Epoch 00006: val_loss improved from 0.06893 to 0.06613, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/30/cp.ckpt
# 225/225 [==============================] - 112s 500ms/step - loss: 0.0430 - dice_coef: 0.9570 - iou: 0.9176 - val_loss: 0.0661 - val_dice_coef: 0.9339 - val_iou: 0.8761
# Epoch 7/10
# 225/225 [==============================] - ETA: 0s - loss: 0.0402 - dice_coef: 0.9598 - iou: 0.9228
# Epoch 00007: val_loss improved from 0.06613 to 0.06438, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/30/cp.ckpt
# 225/225 [==============================] - 112s 500ms/step - loss: 0.0402 - dice_coef: 0.9598 - iou: 0.9228 - val_loss: 0.0644 - val_dice_coef: 0.9356 - val_iou: 0.8792
# Epoch 8/10
# 225/225 [==============================] - ETA: 0s - loss: 0.0381 - dice_coef: 0.9619 - iou: 0.9267
# Epoch 00008: val_loss improved from 0.06438 to 0.06248, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/30/cp.ckpt
# 225/225 [==============================] - 113s 500ms/step - loss: 0.0381 - dice_coef: 0.9619 - iou: 0.9267 - val_loss: 0.0625 - val_dice_coef: 0.9375 - val_iou: 0.8825
# Epoch 9/10
# 225/225 [==============================] - ETA: 0s - loss: 0.0360 - dice_coef: 0.9640 - iou: 0.9307
# Epoch 00009: val_loss improved from 0.06248 to 0.06012, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/30/cp.ckpt
# 225/225 [==============================] - 113s 501ms/step - loss: 0.0360 - dice_coef: 0.9640 - iou: 0.9307 - val_loss: 0.0601 - val_dice_coef: 0.9399 - val_iou: 0.8867
# Epoch 10/10
# 225/225 [==============================] - ETA: 0s - loss: 0.0338 - dice_coef: 0.9662 - iou: 0.9347
# Epoch 00010: val_loss improved from 0.06012 to 0.05895, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/30/cp.ckpt
# 225/225 [==============================] - 113s 501ms/step - loss: 0.0338 - dice_coef: 0.9662 - iou: 0.9347 - val_loss: 0.0590 - val_dice_coef: 0.9410 - val_iou: 0.8888

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.figure()
N = 10
plt.plot(np.arange(0,N), h2.history["loss"], label="train_loss")
plt.plot(np.arange(0,N), h2.history["val_loss"], label = "val_loss")
plt.plot(np.arange(0,N), h2.history["iou"], label = "train_iou_score")
plt.plot(np.arange(0,N), h2.history["val_iou"], label = "val_iou_score")
plt.legend(loc="center right")
plt.title("Training Loss and IOU plot")
plt.xlabel("Epoch")
plt.savefig('UNET_Traininerrorplot_SEGMENTATION_RGB.png')

# %%
plt.plot(np.arange(0,N), h2.history["val_loss"], label = "val_loss")
plt.title("Validation loss plot")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.savefig('UNET_ValLossPlot_SEGMENTATION_V1.2.png')

# %%
plt.plot(np.arange(0,N), h2.history["loss"], label = "val_loss")
plt.title("Training loss plot")
plt.xlabel("Epoch")
plt.ylabel("Training Loss")
plt.savefig('UNET_TrainLossPlot_SEGMENTATION_V1.2.png')

# %% [markdown]
# # **EVALUATION**

# %%
path = "/content/OUHANDS_Siddhant/testing/colour"
maskpath = "/content/OUHANDS_Siddhant/testing/segmentation"
p1 = os.listdir(path)
p1.sort()

m1 = os.listdir(maskpath)
m1.sort()

X_test = np.zeros((len(os.listdir(path)), IMG_HEIGHT, IMG_WIDTH,IMG_CHANNELS),dtype=np.uint8)
Y_test = np.zeros((len(os.listdir(maskpath)), IMG_HEIGHT, IMG_WIDTH,1))
print('creating test data')
n=0
for name in tqdm(p1):
    newpath = os.path.join(path,name)
    img=cv2.imread(newpath)
    img=cv2.resize(img,(IMG_WIDTH,IMG_HEIGHT))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    X_test[n]=img
    n+=1

m=0
for name in tqdm(m1):
    newmaskpath = os.path.join(maskpath,name)
    mpg=cv2.imread(newmaskpath,0)
    mpg=cv2.resize(mpg,(IMG_WIDTH,IMG_HEIGHT))
    mpg=np.expand_dims(mpg,axis=-1)
    Y_test[m]=mpg/255
    m+=1
# Out:
# creating test data
# 100%|██████████| 1000/1000 [00:11<00:00, 90.68it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 547.86it/s]

# %%
X_test =preprocess_input1(X_test)

# %%
plt.imshow(X_test[0])

# %%
plt.imshow(array_to_img(Y_test[0]))

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from sklearn.metrics import f1_score

# %%
def fscore(tp,Images,Masks):
    total=0
    i=0
    fs=0
    for i in range(len(Images)):
        total += 1
        
        tp[i][tp[i]>0.5]=1
        tp[i][tp[i]<0.5]=0

        pred = img_to_array(tp[i]).astype(int)
        label = img_to_array(np.squeeze(Masks[i], axis=2)).astype(int)
        flat_pred = np.ravel(pred)
        flat_label = np.ravel(label)

        fs += f1_score(flat_label,flat_pred, average='micro')

    fs=fs/total

    return fs

# %% [markdown]
# ##20 epochs

# %%
model.save("")

# %%
 #    ######evaluate#####
checkpoint_path_segmentUNET = "/content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/cp.ckpt"
model.load_weights(checkpoint_path_segmentUNET)

# %%
y_pred=model.predict(X_test)

# %%
f=fscore(y_pred,X_test,Y_test)
print(f)
# Out:
# 0.9783507031249992

# %% [markdown]
# AEC_EE_RESNET 18 encoder LINKNET
#
# 20 epochs
#
# IoU socre is: 0.8299967067687382
#
# F - 0.9783507031249992

# %%
## Jaccard Index ( IoU )

#y_pred=model.predict(X_test)
y_pred_thresholded = y_pred > 0.5

intersection = np.logical_and(Y_test, y_pred_thresholded)
union = np.logical_or(Y_test, y_pred_thresholded)
iou_score = np.sum(intersection) / np.sum(union)
print("IoU socre is: ", iou_score)
# Out:
# IoU socre is:  0.8299967067687382

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(X_test[270]))
#plt.title('TEST IMAGE')

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(Y_test[270]), cmap = 'gray')
#plt.title('TEST SEGMENTATION MASK GROUND TRUTH', fontsize=8)

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(y_pred[270]), cmap = 'gray')
#plt.title('TEST SEGMENTATION MASK OBTAINED FROM DEEP LEARNING MODULE', fontsize=8)

# %%
#Prediction test
import random
import numpy as np
image_number = random.randint(0, len(X_test))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(X_test[image_number])
plt.subplot(122)
plt.imshow(array_to_img(y_pred[image_number]), cmap='gray')
plt.show()

# %%
x_test_single = np.expand_dims(X_test[200], axis = 0)

# %%
import time
start_time = time.time()
y_single = model.predict(x_test_single)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.15967488288879395 seconds ---

# %% [markdown]
# ##30Epochs

# %%
 #    ######evaluate#####
checkpoint_path_segmentUNET = "/content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_Resnet18/ASPP/30/cp.ckpt"
model.load_weights(checkpoint_path_segmentUNET)

# %%
y_pred=model.predict(X_test)

# %%
f=fscore(y_pred,X_test,Y_test)
print(f)
# Out:
# 0.9801724121093752

# %% [markdown]
# LINKNET _ ASPP
#
# F - 0.9801724121093752
#
# IoU socre is:  0.8403416923529685

# %%
## Jaccard Index ( IoU )

#y_pred=model.predict(X_test)
y_pred_thresholded = y_pred > 0.5

intersection = np.logical_and(Y_test, y_pred_thresholded)
union = np.logical_or(Y_test, y_pred_thresholded)
iou_score = np.sum(intersection) / np.sum(union)
print("IoU socre is: ", iou_score)
# Out:
# IoU socre is:  0.8403416923529685

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(X_test[50]))
#plt.title('TEST IMAGE')

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(Y_test[50]), cmap = 'gray')
#plt.title('TEST SEGMENTATION MASK GROUND TRUTH', fontsize=8)

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(y_pred[50]), cmap = 'gray')
#plt.title('TEST SEGMENTATION MASK OBTAINED FROM DEEP LEARNING MODULE', fontsize=8)

# %%
#Prediction test
import random
import numpy as np
image_number = random.randint(0, len(X_test))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(X_test[image_number])
plt.subplot(122)
plt.imshow(array_to_img(y_pred[image_number]), cmap='gray')
plt.show()

# %%
import time
x_test_single = np.expand_dims(X_test[8], axis = 0)

start_time = time.time()
y_single = model.predict(x_test_single)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.08934760093688965 seconds ---

# %% [markdown]
# #SAVE THE MODEL

# %%
model.save("")
