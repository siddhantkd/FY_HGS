# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhantkd/FY_HGS/blob/main/AEC_EE_Model_SKD_LinkNET%5Bmobilenetv2%5D_ASPP%2Bsam_150epochs%2BDROPOUT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **AEC _ EE - NET**
#
# 1. ResNet18_LINKNET with ASPP
#
# LINKNET _ ASPP [ 512 deconv filters ]
#
# BEST 30 epochs
#
# > F - 0.9801724121093752
#
# > IoU socre is:  0.8403416923529685
#
# ASPP [ 256 deconv filters ]
#
# > F 0.9805174218749996
#
# > IOU : IoU socre is:  0.8417632228496972 / 0.8403  ( no y test change )
#
# > Epochs 60 ( CONVERGED )
#
#
# 2. mobilenetv2_LINKNET with ASPP_64
#
# ASPP [ 64 deconv filters ]
#
# > F - 0.9800259472656246
#
# > IoU socre is: 0.8349840733116369
#
# > Epochs 30 ( CONVERGED )
#
# 3. mobilenetv2_LINKNET with sam + ASPPP

# %% [markdown]
# #IMPORT AND DRIVE LOAD

# %%
import cv2
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import keras
from tqdm import tqdm
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
# !nvidia-smi
# Out:
# Mon Jan 17 04:04:23 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %% [markdown]
# #Data Loading

# %%
# !unzip '/content/drive/MyDrive/OUHANDS/OUHANDS_Siddhant.zip'

# %%
IMG_WIDTH = 320
IMG_HEIGHT = 320
IMG_CHANNELS = 3

# %%
path = "/content/OUHANDS_Siddhant/training/colour"
maskpath = "/content/OUHANDS_Siddhant/training/segmentation"

X_train = np.zeros((len(os.listdir(path)), IMG_HEIGHT, IMG_WIDTH,IMG_CHANNELS),dtype=np.uint8)
Y_train = np.zeros((len(os.listdir(maskpath)), IMG_HEIGHT, IMG_WIDTH,1))
print('creating input data')
n=0
for name in tqdm(os.listdir(path)):
    newpath = os.path.join(path,name)
    img=cv2.imread(newpath)
    img=cv2.resize(img,(IMG_WIDTH,IMG_HEIGHT))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    X_train[n]=img
    n+=1

m=0
for name in tqdm(os.listdir(maskpath)):
    newmaskpath = os.path.join(maskpath,name)
    mpg=cv2.imread(newmaskpath)
    mpg=cv2.resize(mpg,(IMG_WIDTH,IMG_HEIGHT))
    mpg = cv2.cvtColor(mpg, cv2.COLOR_BGR2GRAY)
    ret, mpg = cv2.threshold(mpg, 120, 255, cv2.THRESH_BINARY)
    mpg=np.expand_dims(mpg,axis=-1)
    Y_train[m]=mpg/255
    m+=1
# Out:
# creating input data
# 100%|██████████| 2000/2000 [00:19<00:00, 104.38it/s]
# 100%|██████████| 2000/2000 [00:05<00:00, 355.64it/s]

# %%
#Sanity check, view few images
import random
import numpy as np
image_number = random.randint(0, len(X_train))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(X_train[image_number])
plt.subplot(122)
plt.imshow(array_to_img(Y_train[image_number]), cmap='gray')
plt.show()

# %%
np.unique(Y_train)
# Out:
# array([0., 1.])

# %%
print(X_train.shape, Y_train.shape)
# Out:
# (2000, 320, 320, 3) (2000, 320, 320, 1)

# %% [markdown]
# # AEC_EE Model

# %%
from tensorflow.keras.layers import Conv2D, Activation, BatchNormalization, Dropout
from tensorflow.keras.layers import UpSampling2D, Input, Concatenate, Conv2DTranspose, Add, AveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.layers import *

# %%
def ASPP(inputs):

    conv_filters = 64
    """ Image Pooling """
    shape = inputs.shape
    y1 = AveragePooling2D(pool_size=(shape[1], shape[2]))(inputs)
    y1 = Conv2D(conv_filters, 1, padding="same", use_bias=False)(y1)
    y1 = BatchNormalization()(y1)
    y1 = Activation("relu")(y1)
    y1 = UpSampling2D((shape[1], shape[2]), interpolation="bilinear")(y1)

    """ 1x1 conv """
    y2 = Conv2D(conv_filters, 1, padding="same", use_bias=False)(inputs)
    y2 = BatchNormalization()(y2)
    y2 = Activation("relu")(y2)

    """ 3x3 conv rate=6 """
    y3 = Conv2D(conv_filters, 3, padding="same", use_bias=False, dilation_rate=6)(inputs)
    y3 = BatchNormalization()(y3)
    y3 = Activation("relu")(y3)

    """ 3x3 conv rate=12 """
    y4 = Conv2D(conv_filters, 3, padding="same", use_bias=False, dilation_rate=12)(inputs)
    y4 = BatchNormalization()(y4)
    y4 = Activation("relu")(y4)

    """ 3x3 conv rate=18 """
    y5 = Conv2D(conv_filters, 3, padding="same", use_bias=False, dilation_rate=18)(inputs)
    y5 = BatchNormalization()(y5)
    y5 = Activation("relu")(y5)

    y = Concatenate()([y1, y2, y3, y4, y5])
    y = Conv2D(conv_filters, 1, padding="same", use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation("relu")(y)

    return y

# %%
def sa_block(inputs):
    """
    Spatial Attention Module utilizing the inter-spatial relationship of features.
    """
    kernel_size = 3

    # avg_pool = Lambda(lambda x: K.mean(x, axis=-1, keepdims=True))(inputs)
    # max_pool = Lambda(lambda x: K.max(x, axis=-1, keepdims=True))(inputs)
    avg_pool = K.mean(inputs, axis=-1, keepdims=True)
    max_pool = K.max(inputs, axis=-1, keepdims=True)

    x = Concatenate()([avg_pool, max_pool])

    x = Conv2D(1, kernel_size, padding='same', activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(x)

    outputs = Multiply()([inputs, x])
    return outputs

# %%
"""Skip connections as per SM Models LINKnet with backbone mobilenetv2"""

# LATEST MODEL - LINKNET only

def build_LinkNet_mobilenetv2():    
  model = tf.keras.applications.MobileNetV2(input_shape=(320, 320,3), include_top=False, weights="imagenet")

  """ Skip Connections """

  s1 = model.get_layer("block_1_expand_relu").output         ## (160, 160)
  s1 = sa_block(s1)
  s2 = model.get_layer("block_3_expand_relu").output         ## ( 80, 80)
  s2 = sa_block(s2)
  s3 = model.get_layer("block_6_expand_relu").output         ## (40, 40)
  s3 = sa_block(s3)
  s4 = model.get_layer("block_13_expand_relu").output         ## (20, 20)
  s4 = sa_block(s4)

  #print(s1.shape, s2.shape, s3.shape, s4.shape)

  """ Bridge """

  b1 = model.get_layer("out_relu").output
  b1 = ASPP(b1)
  #print(b1.shape)

  """ Decoder """
  x = Conv2D(320, (1,1), kernel_initializer='he_normal', padding = 'same')(b1)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = tf.keras.layers.UpSampling2D( size=(2, 2), interpolation='nearest')(x)

  x = Conv2D(320, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Conv2D(576, (1,1), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Add()([x, s4]) # ADD 1

  x = Conv2D(144, (1,1), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = tf.keras.layers.UpSampling2D( size=(2, 2), interpolation='nearest')(x)

  x = Conv2D(144, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Conv2D(192, (1,1), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Add()([x, s3]) # ADD 2

  x = Conv2D(48, (1,1), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = tf.keras.layers.UpSampling2D( size=(2, 2), interpolation='nearest')(x)

  x = Conv2D(48, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Conv2D(144, (1,1), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Add()([x, s2]) # ADD 3

  x = Conv2D(36, (1,1), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = tf.keras.layers.UpSampling2D( size=(2, 2), interpolation='nearest')(x)

  x = Conv2D(36, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Conv2D(96, (1,1), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Add()([x, s1]) # ADD 4

  x = Conv2D(24, (1,1), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = tf.keras.layers.UpSampling2D( size=(2, 2), interpolation='nearest')(x)

  x = Conv2D(24, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Conv2D(16, (1,1), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Dropout(0.15)(x)

  outputs = Conv2D(1, 1, kernel_initializer='he_normal',padding="same")(x)
  outputs = Activation('sigmoid')(outputs)

  model = keras.models.Model(inputs=[model.input], outputs=[outputs])  

  #print(model.summary())

  return model

# %%
model = build_LinkNet_mobilenetv2()
print(model.summary())
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# 9420800/9406464 [==============================] - 0s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 320, 320, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 160, 160, 32  864         ['input_1[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 160, 160, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 160, 160, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 160, 160, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 160, 160, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
#  expanded_conv_depthwise_relu (  (None, 160, 160, 32  0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          )                                ]']
#
#  expanded_conv_project (Conv2D)  (None, 160, 160, 16  512        ['expanded_conv_depthwise_relu[0]
#                                 )                                [0]']
#
#  expanded_conv_project_BN (Batc  (None, 160, 160, 16  64         ['expanded_conv_project[0][0]']
#  hNormalization)                )
#
#  block_1_expand (Conv2D)        (None, 160, 160, 96  1536        ['expanded_conv_project_BN[0][0]'
#                                 )                                ]
#
#  block_1_expand_BN (BatchNormal  (None, 160, 160, 96  384        ['block_1_expand[0][0]']
#  ization)                       )
#
#  block_1_expand_relu (ReLU)     (None, 160, 160, 96  0           ['block_1_expand_BN[0][0]']
#                                 )
#
#  block_1_pad (ZeroPadding2D)    (None, 161, 161, 96  0           ['block_1_expand_relu[0][0]']
#                                 )
#
#  block_1_depthwise (DepthwiseCo  (None, 80, 80, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 80, 80, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 80, 80, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 80, 80, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 80, 80, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 80, 80, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 80, 80, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 80, 80, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 80, 80, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 80, 80, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 80, 80, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 80, 80, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 80, 80, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 80, 80, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 80, 80, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 80, 80, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 80, 80, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 81, 81, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 40, 40, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 40, 40, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 40, 40, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 40, 40, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 40, 40, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 40, 40, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 40, 40, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 40, 40, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 40, 40, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 40, 40, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 40, 40, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 40, 40, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 40, 40, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 40, 40, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 40, 40, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 40, 40, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 40, 40, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 40, 40, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 40, 40, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 40, 40, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 40, 40, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 40, 40, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 40, 40, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 40, 40, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 40, 40, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 40, 40, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 41, 41, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 20, 20, 192)  1728       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 20, 20, 192)  768        ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 20, 20, 192)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 20, 20, 64)   12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 20, 20, 64)  256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 20, 20, 384)  24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 20, 20, 384)  1536       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 20, 20, 384)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 20, 20, 384)  3456       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 20, 20, 384)  1536       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 20, 20, 384)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 20, 20, 64)   24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 20, 20, 64)  256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 20, 20, 64)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 20, 20, 384)  24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 20, 20, 384)  1536       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 20, 20, 384)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 20, 20, 384)  3456       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 20, 20, 384)  1536       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 20, 20, 384)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 20, 20, 64)   24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 20, 20, 64)  256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 20, 20, 64)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 20, 20, 384)  24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 20, 20, 384)  1536       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 20, 20, 384)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 20, 20, 384)  3456       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 20, 20, 384)  1536       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 20, 20, 384)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 20, 20, 64)   24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 20, 20, 64)  256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 20, 20, 64)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 20, 20, 384)  24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 20, 20, 384)  1536       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 20, 20, 384)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 20, 20, 384)  3456       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 20, 20, 384)  1536       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 20, 20, 384)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 20, 20, 96)   36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 20, 20, 96)  384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 20, 20, 576)  55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 20, 20, 576)  2304       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 20, 20, 576)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 20, 20, 576)  5184       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 20, 20, 576)  2304       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 20, 20, 576)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 20, 20, 96)   55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 20, 20, 96)  384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 20, 20, 96)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 20, 20, 576)  55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 20, 20, 576)  2304       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 20, 20, 576)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 20, 20, 576)  5184       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 20, 20, 576)  2304       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 20, 20, 576)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 20, 20, 96)   55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 20, 20, 96)  384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 20, 20, 96)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 20, 20, 576)  55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 20, 20, 576)  2304       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 20, 20, 576)  0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 21, 21, 576)  0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 10, 10, 576)  5184       ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 10, 10, 576)  2304       ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 10, 10, 576)  0          ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 10, 10, 160)  92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 10, 10, 160)  640        ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 10, 10, 960)  153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 10, 10, 960)  3840       ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 10, 10, 960)  0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 10, 10, 960)  8640       ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 10, 10, 960)  3840       ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 10, 10, 960)  0          ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 10, 10, 160)  153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 10, 10, 160)  640        ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 10, 10, 160)  0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 10, 10, 960)  153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 10, 10, 960)  3840       ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 10, 10, 960)  0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 10, 10, 960)  8640       ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 10, 10, 960)  3840       ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 10, 10, 960)  0          ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 10, 10, 160)  153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 10, 10, 160)  640        ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 10, 10, 160)  0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 10, 10, 960)  153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 10, 10, 960)  3840       ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 10, 10, 960)  0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 10, 10, 960)  8640       ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 10, 10, 960)  3840       ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 10, 10, 960)  0          ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 10, 10, 320)  307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 10, 10, 320)  1280       ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 10, 10, 1280  409600      ['block_16_project_BN[0][0]']
#                                 )
#
#  Conv_1_bn (BatchNormalization)  (None, 10, 10, 1280  5120       ['Conv_1[0][0]']
#                                 )
#
#  out_relu (ReLU)                (None, 10, 10, 1280  0           ['Conv_1_bn[0][0]']
#                                 )
#
#  average_pooling2d (AveragePool  (None, 1, 1, 1280)  0           ['out_relu[0][0]']
#  ing2D)
#
#  conv2d_4 (Conv2D)              (None, 1, 1, 64)     81920       ['average_pooling2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 1, 1, 64)    256         ['conv2d_4[0][0]']
#  alization)
#
#  conv2d_5 (Conv2D)              (None, 10, 10, 64)   81920       ['out_relu[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 10, 10, 64)   737280      ['out_relu[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 10, 10, 64)   737280      ['out_relu[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 10, 10, 64)   737280      ['out_relu[0][0]']
#
#  activation (Activation)        (None, 1, 1, 64)     0           ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 10, 10, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_2 (BatchNo  (None, 10, 10, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, 10, 10, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 10, 10, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  up_sampling2d (UpSampling2D)   (None, 10, 10, 64)   0           ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 10, 10, 64)   0           ['batch_normalization_1[0][0]']
#
#  activation_2 (Activation)      (None, 10, 10, 64)   0           ['batch_normalization_2[0][0]']
#
#  activation_3 (Activation)      (None, 10, 10, 64)   0           ['batch_normalization_3[0][0]']
#
#  activation_4 (Activation)      (None, 10, 10, 64)   0           ['batch_normalization_4[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 10, 10, 320)  0           ['up_sampling2d[0][0]',
#                                                                   'activation_1[0][0]',
#                                                                   'activation_2[0][0]',
#                                                                   'activation_3[0][0]',
#                                                                   'activation_4[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 10, 10, 64)   20480       ['concatenate_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 10, 10, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 10, 10, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 10, 10, 320)  20800       ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 10, 10, 320)  1280       ['conv2d_10[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 10, 10, 320)  0           ['batch_normalization_6[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 20, 20, 320)  0          ['activation_6[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 20, 20, 320)  921920      ['up_sampling2d_1[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 20, 20, 320)  1280       ['conv2d_11[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 20, 20, 320)  0           ['batch_normalization_7[0][0]']
#
#  tf.math.reduce_mean_3 (TFOpLam  (None, 20, 20, 1)   0           ['block_13_expand_relu[0][0]']
#  bda)
#
#  tf.math.reduce_max_3 (TFOpLamb  (None, 20, 20, 1)   0           ['block_13_expand_relu[0][0]']
#  da)
#
#  conv2d_12 (Conv2D)             (None, 20, 20, 576)  184896      ['activation_7[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 20, 20, 2)    0           ['tf.math.reduce_mean_3[0][0]',
#                                                                   'tf.math.reduce_max_3[0][0]']
#
# ...
#
#  activation_9 (Activation)      (None, 20, 20, 144)  0           ['batch_normalization_9[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 40, 40, 144)  0          ['activation_9[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 40, 40, 144)  186768      ['up_sampling2d_2[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 40, 40, 144)  576        ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 40, 40, 144)  0           ['batch_normalization_10[0][0]']
#
#  tf.math.reduce_mean_2 (TFOpLam  (None, 40, 40, 1)   0           ['block_6_expand_relu[0][0]']
#  bda)
#
#  tf.math.reduce_max_2 (TFOpLamb  (None, 40, 40, 1)   0           ['block_6_expand_relu[0][0]']
#  da)
#
#  conv2d_15 (Conv2D)             (None, 40, 40, 192)  27840       ['activation_10[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 40, 40, 2)    0           ['tf.math.reduce_mean_2[0][0]',
#                                                                   'tf.math.reduce_max_2[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 40, 40, 192)  768        ['conv2d_15[0][0]']
#  ormalization)
#
#  conv2d_2 (Conv2D)              (None, 40, 40, 1)    18          ['concatenate_2[0][0]']
#
#  activation_11 (Activation)     (None, 40, 40, 192)  0           ['batch_normalization_11[0][0]']
#
#  multiply_2 (Multiply)          (None, 40, 40, 192)  0           ['block_6_expand_relu[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  add_1 (Add)                    (None, 40, 40, 192)  0           ['activation_11[0][0]',
#                                                                   'multiply_2[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 40, 40, 48)   9264        ['add_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 40, 40, 48)  192         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 40, 40, 48)   0           ['batch_normalization_12[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 80, 80, 48)  0           ['activation_12[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 80, 80, 48)   20784       ['up_sampling2d_3[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 80, 80, 48)  192         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 80, 80, 48)   0           ['batch_normalization_13[0][0]']
#
#  tf.math.reduce_mean_1 (TFOpLam  (None, 80, 80, 1)   0           ['block_3_expand_relu[0][0]']
#  bda)
#
#  tf.math.reduce_max_1 (TFOpLamb  (None, 80, 80, 1)   0           ['block_3_expand_relu[0][0]']
#  da)
#
#  conv2d_18 (Conv2D)             (None, 80, 80, 144)  7056        ['activation_13[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 80, 80, 2)    0           ['tf.math.reduce_mean_1[0][0]',
#                                                                   'tf.math.reduce_max_1[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 80, 80, 144)  576        ['conv2d_18[0][0]']
#  ormalization)
#
#  conv2d_1 (Conv2D)              (None, 80, 80, 1)    18          ['concatenate_1[0][0]']
#
#  activation_14 (Activation)     (None, 80, 80, 144)  0           ['batch_normalization_14[0][0]']
#
#  multiply_1 (Multiply)          (None, 80, 80, 144)  0           ['block_3_expand_relu[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  add_2 (Add)                    (None, 80, 80, 144)  0           ['activation_14[0][0]',
#                                                                   'multiply_1[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 80, 80, 36)   5220        ['add_2[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 80, 80, 36)  144         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 80, 80, 36)   0           ['batch_normalization_15[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 160, 160, 36  0          ['activation_15[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 160, 160, 36  11700       ['up_sampling2d_4[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 160, 160, 36  144        ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 160, 160, 36  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  tf.math.reduce_mean (TFOpLambd  (None, 160, 160, 1)  0          ['block_1_expand_relu[0][0]']
#  a)
#
#  tf.math.reduce_max (TFOpLambda  (None, 160, 160, 1)  0          ['block_1_expand_relu[0][0]']
#  )
#
#  conv2d_21 (Conv2D)             (None, 160, 160, 96  3552        ['activation_16[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 160, 160, 2)  0           ['tf.math.reduce_mean[0][0]',
#                                                                   'tf.math.reduce_max[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 160, 160, 96  384        ['conv2d_21[0][0]']
#  ormalization)                  )
#
#  conv2d (Conv2D)                (None, 160, 160, 1)  18          ['concatenate[0][0]']
#
#  activation_17 (Activation)     (None, 160, 160, 96  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  multiply (Multiply)            (None, 160, 160, 96  0           ['block_1_expand_relu[0][0]',
#                                 )                                 'conv2d[0][0]']
#
#  add_3 (Add)                    (None, 160, 160, 96  0           ['activation_17[0][0]',
#                                 )                                 'multiply[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 160, 160, 24  2328        ['add_3[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 160, 160, 24  96         ['conv2d_22[0][0]']
#  ormalization)                  )
#
#  activation_18 (Activation)     (None, 160, 160, 24  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  up_sampling2d_5 (UpSampling2D)  (None, 320, 320, 24  0          ['activation_18[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 320, 320, 24  5208        ['up_sampling2d_5[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 320, 320, 24  96         ['conv2d_23[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 320, 320, 24  0           ['batch_normalization_19[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 320, 320, 16  400         ['activation_19[0][0]']
#                                 )
#
#  batch_normalization_20 (BatchN  (None, 320, 320, 16  64         ['conv2d_24[0][0]']
#  ormalization)                  )
#
#  activation_20 (Activation)     (None, 320, 320, 16  0           ['batch_normalization_20[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 320, 320, 16  0           ['activation_20[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 320, 320, 1)  17          ['dropout[0][0]']
#
#  activation_21 (Activation)     (None, 320, 320, 1)  0           ['conv2d_25[0][0]']
#
# ==================================================================================================
# Total params: 6,155,265
# Trainable params: 6,116,049
# Non-trainable params: 39,216
# __________________________________________________________________________________________________
# None

# %%
from tensorflow.keras.optimizers import Adam

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
model.compile(loss=dice_loss, 
              optimizer=Adam(1e-4), 
              metrics=[dice_coef, iou, "accuracy"])

# %% [markdown]
# # MODEL TRAINING

# %% [markdown]
# ## 150 epochs

# %% [markdown]
# BATCH SIZE = 16
#
#
# DROPOUT

# %%
#Model Checkpoint
checkpoint_path_segment = "/content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_mobilenetv2/SAM_ASPP/0-150_callback/cp.ckpt"
model_checkpoint_segment = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path_segmentUNET,
                                                  save_weights_only=True,
                                                  monitor='val_loss', save_best_only=True,
                                                  verbose=1)

# %%
history = model.fit(X_train, Y_train, validation_data = (X_test, Y_test), batch_size=16, epochs=150, callbacks = [model_checkpoint_segment])
# Out:
# Epoch 1/150
# 125/125 [==============================] - ETA: 0s - loss: 0.6855 - dice_coef: 0.3145 - iou: 0.1879 - accuracy: 0.5986
# Epoch 00001: val_loss improved from inf to 0.72734, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_mobilenetv2/SAM_ASPP/0-150_callback/cp.ckpt
# 125/125 [==============================] - 69s 404ms/step - loss: 0.6855 - dice_coef: 0.3145 - iou: 0.1879 - accuracy: 0.5986 - val_loss: 0.7273 - val_dice_coef: 0.2730 - val_iou: 0.1591 - val_accuracy: 0.3447
# Epoch 2/150
# 125/125 [==============================] - ETA: 0s - loss: 0.6033 - dice_coef: 0.3967 - iou: 0.2482 - accuracy: 0.9141
# Epoch 00002: val_loss improved from 0.72734 to 0.62493, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_mobilenetv2/SAM_ASPP/0-150_callback/cp.ckpt
# 125/125 [==============================] - 47s 377ms/step - loss: 0.6033 - dice_coef: 0.3967 - iou: 0.2482 - accuracy: 0.9141 - val_loss: 0.6249 - val_dice_coef: 0.3755 - val_iou: 0.2328 - val_accuracy: 0.8992
# Epoch 3/150
# 125/125 [==============================] - ETA: 0s - loss: 0.5752 - dice_coef: 0.4248 - iou: 0.2704 - accuracy: 0.9695
# Epoch 00003: val_loss improved from 0.62493 to 0.57699, saving model to /content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_mobilenetv2/SAM_ASPP/0-150_callback/cp.ckpt
# 125/125 [==============================] - 47s
val_loss did not improve from 0.09048
# 125/125 [==============================] - 47s 374ms/step - loss: 0.0145 - dice_coef: 0.9855 - iou: 0.9713 - accuracy: 0.9968 - val_loss: 0.0940 - val_dice_coef: 0.9062 - val_iou: 0.8325 - val_accuracy: 0.9795
# Epoch 134/150
# 125/125 [==============================] - ETA: 0s - loss: 0.0145 - dice_coef: 0.9855 - iou: 0.9714 - accuracy: 0.9968
# Epoch 00134: val_loss did not improve from 0.09048
# 125/125 [==============================] - 47s 373ms/step - loss: 0.0145 - dice_coef: 0.9855 - iou: 0.9714 - accuracy: 0.9968 - val_loss: 0.0934 - val_dice_coef: 0.9067 - val_iou: 0.8332 - val_accuracy: 0.9796
# Epoch 135/150
# 125/125 [==============================] - ETA: 0s - loss: 0.0145 - dice_coef: 0.9855 - iou: 0.9715 - accuracy: 0.9968
# Epoch 00135: val_loss did not improve from 0.09048
# 125/125 [==============================] - 47s 373ms/step - loss: 0.0145 - dice_coef: 0.9855 - iou: 0.9715 - accuracy: 0.9968 - val_loss: 0.0932 - val_dice_coef: 0.9070 - val_iou: 0.8337 - val_accuracy: 0.9797
# Epoch 136/150
# 125/125 [==============================] - ETA: 0s - loss: 0.0146 - dice_coef: 0.9854 - iou: 0.9713 - accuracy: 0.9968
# Epoch 00136: val_loss did not improve from 0.09048
# 125/125 [==============================] - 47s 372ms/step - loss: 0.0146 - dice_coef: 0.9854 - iou: 0.9713 - accuracy: 0.9968 - val_loss: 0.0947 - val_dice_coef: 0.9054 - val_iou: 0.8312 - val_accuracy: 0.9793
# Epoch 137/150
# 125/125 [==============================] - ETA: 0s - loss: 0.0144 - dice_coef: 0.9856 - iou: 0.9716 - accuracy: 0.9968
# Epoch 00137: val_loss did not improve from 0.09048
# 125/125 [==============================] - 46s 372ms/step - loss: 0.0144 - dice_coef: 0.9856 - iou: 0.9716 - accuracy: 0.9968 - val_loss: 0.0923 - val_dice_coef: 0.9079 - val_iou: 0.8351 - val_accuracy: 0.9799
# Epoch 138/150
# 125/125 [==============================] - ETA: 0s - loss: 0.0144 - dice_coef: 0.9856 - iou: 0.9716 - accuracy: 0.9968
# Epoch 00138: val_loss did not improve from 0.09048
# 125/125 [==============================] - 47s 373ms/step - loss: 0.0144 - dice_coef: 0.9856 - iou: 0.9716 - accuracy: 0.9968 - val_loss: 0.0962 - val_dice_coef: 0.9039 - val_iou: 0.8289 - val_accuracy: 0.9790
# Epoch 139/150
# 125/125 [==============================] - ETA: 0s - loss: 0.0144 - dice_coef: 0.9856 - iou: 0.9717 - accuracy: 0.9968
# Epoch 00139: val_loss did not improve from 0.09048
# 125/125 [==============================] - 47s 373ms/step - loss: 0.0144 - dice_coef: 0.9856 - iou: 0.9717 - accuracy: 0.9968 - val_loss: 0.0942 - val_dice_coef: 0.9061 - val_iou: 0.8323 - val_accuracy: 0.9794
# Epoch 140/150
# 125/125 [==============================] - ETA: 0s - loss: 0.0143 - dice_coef: 0.9857 - iou: 0.9719 - accuracy: 0.9968
# Epoch 00140: val_loss did not improve from 0.09048
# 125/125 [==============================] - 47s 374ms/step - loss: 0.0143 - dice_coef: 0.9857 - iou: 0.9719 - accuracy: 0.9968 - val_loss: 0.0943 - val_dice_coef: 0.9059 - val_iou: 0.8319 - val_accuracy: 0.9796
# Epoch 141/150
# 125/125 [==============================] - ETA: 0s - loss: 0.0144 - dice_coef: 0.9856 - iou: 0.9716 - accuracy: 0.9968
# Epoch 00141: val_loss did not improve from 0.09048
# 125/125 [==============================] - 47s 374ms/step - loss: 0.0144 - dice_coef: 0.9856 - iou: 0.9716 - accuracy: 0.9968 - val_loss: 0.0917 - val_dice_coef: 0.9085 - val_iou: 0.8362 - val_accuracy: 0.9799
# Epoch 142/150
# 125/125 [==============================] - ETA: 0s - loss: 0.0142 - dice_coef: 0.9858 - iou: 0.9720 - accuracy: 0.9969
# Epoch 00142: val_loss did not improve from 0.09048
# 125/125 [==============================] - 47s 373ms/step - loss: 0.0142 - dice_coef: 0.9858 - iou: 0.9720 - accuracy: 0.9969 - val_loss: 0.0922 - val_dice_coef: 0.9080 - val_iou: 0.8352 - val_accuracy: 0.9799
# Epoch 143/150
# 125/125 [==============================] - ETA: 0s - loss: 0.0142 - dice_coef: 0.9858 - iou: 0.9720 - accuracy: 0.9969
# Epoch 00143: val_loss did not improve from 0.09048
# 125/125 [==============================] - 47s 373ms/step - loss: 0.0142 - dice_coef: 0.9858 - iou: 0.9720 - accuracy: 0.9969 - val_loss: 0.0938 - val_dice_coef: 0.9064 - val_iou: 0.8325 - val_accuracy: 0.9795
# Epoch 144/150
# 125/125 [==============================] - ETA: 0s - loss: 0.0141 - dice_coef: 0.9859 - iou: 0.9722 - accuracy: 0.9969
# Epoch 00144: val_loss did not improve from 0.09048
# 125/125 [==============================] - 47s 373ms/step - loss: 0.0141 - dice_coef: 0.9859 - iou: 0.9722 - accuracy: 0.9969 - val_loss: 0.0944 - val_dice_coef: 0.9058 - val_iou: 0.8317 - val_accuracy: 0.9794
# Epoch 145/150
# 125/125 [==============================] - ETA: 0s - loss: 0.0141 - dice_coef: 0.9859 - iou: 0.9722 - accuracy: 0.9969
# Epoch 00145: val_loss did not improve from 0.09048
# 125/125 [==============================] - 47s 373ms/step - loss: 0.0141 - dice_coef: 0.9859 - iou: 0.9722 - accuracy: 0.9969 - val_loss: 0.0938 - val_dice_coef: 0.9063 - val_iou: 0.8325 - val_accuracy: 0.9795
# Epoch 146/150
# 125/125 [==============================] - ETA: 0s - loss: 0.0141 - dice_coef: 0.9859 - iou: 0.9723 - accuracy: 0.9969
# Epoch 00146: val_loss did not improve from 0.09048
# 125/125 [==============================] - 47s 374ms/step - loss: 0.0141 - dice_coef: 0.9859 - iou: 0.9723 - accuracy: 0.9969 - val_loss: 0.0959 - val_dice_coef: 0.9042 - val_iou: 0.8291 - val_accuracy: 0.9790
# Epoch 147/150
# 125/125 [==============================] - ETA: 0s - loss: 0.0140 - dice_coef: 0.9860 - iou: 0.9724 - accuracy: 0.9969
# Epoch 00147: val_loss did not improve from 0.09048
# 125/125 [==============================] - 46s 372ms/step - loss: 0.0140 - dice_coef: 0.9860 - iou: 0.9724 - accuracy: 0.9969 - val_loss: 0.0934 - val_dice_coef: 0.9067 - val_iou: 0.8331 - val_accuracy: 0.9795
# Epoch 148/150
# 125/125 [==============================] - ETA: 0s - loss: 0.0140 - dice_coef: 0.9860 - iou: 0.9723 - accuracy: 0.9969
# Epoch 00148: val_loss did not improve from 0.09048
# 125/125 [==============================] - 47s 373ms/step - loss: 0.0140 - dice_coef: 0.9860 - iou: 0.9723 - accuracy: 0.9969 - val_loss: 0.0940 - val_dice_coef: 0.9061 - val_iou: 0.8321 - val_accuracy: 0.9793
# Epoch 149/150
# 125/125 [==============================] - ETA: 0s - loss: 0.0141 - dice_coef: 0.9859 - iou: 0.9721 - accuracy: 0.9969
# Epoch 00149: val_loss did not improve from 0.09048
# 125/125 [==============================] - 47s 373ms/step - loss: 0.0141 - dice_coef: 0.9859 - iou: 0.9721 - accuracy: 0.9969 - val_loss: 0.0938 - val_dice_coef: 0.9063 - val_iou: 0.8325 - val_accuracy: 0.9795
# Epoch 150/150
# 125/125 [==============================] - ETA: 0s - loss: 0.0140 - dice_coef: 0.9860 - iou: 0.9724 - accuracy: 0.9969
# Epoch 00150: val_loss did not improve from 0.09048
# 125/125 [==============================] - 47s 372ms/step - loss: 0.0140 - dice_coef: 0.9860 - iou: 0.9724 - accuracy: 0.9969 - val_loss: 0.0958 - val_dice_coef: 0.9042 - val_iou: 0.8290 - val_accuracy: 0.9790

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.figure()
N = 150
plt.plot(np.arange(0,N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0,N), history.history["val_loss"], label = "val_loss")
plt.plot(np.arange(0,N), history.history["iou"], label = "train_iou_score")
plt.plot(np.arange(0,N), history.history["val_iou"], label = "val_iou_score")
plt.legend(loc="center right")
plt.title("Training Loss and IOU plot")
plt.xlabel("Epochs")
plt.savefig('UNET_Traininerrorplot_SEGMENTATION_RGB.png')

# %%
plt.plot(np.arange(0,N), history.history["accuracy"])
plt.title("Training accuracy plot")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.plot(np.arange(0,N), history.history["val_accuracy"], label = "val_accuracy")
plt.title("Validation accuracy plot")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.plot(np.arange(0,N), history.history["val_loss"], label = "val_loss")
plt.title("Validation loss plot")
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.plot(np.arange(0,N), history.history["loss"], label = "val_loss")
plt.title("Training loss plot")
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %% [markdown]
# # **EVALUATION**

# %%
path = "/content/OUHANDS_Siddhant/testing/colour"
maskpath = "/content/OUHANDS_Siddhant/testing/segmentation"
p1 = os.listdir(path)
p1.sort()

m1 = os.listdir(maskpath)
m1.sort()

X_test = np.zeros((len(os.listdir(path)), IMG_HEIGHT, IMG_WIDTH,IMG_CHANNELS),dtype=np.uint8)
Y_test = np.zeros((len(os.listdir(maskpath)), IMG_HEIGHT, IMG_WIDTH,1))
print('creating test data')
n=0
for name in tqdm(p1):
    newpath = os.path.join(path,name)
    img=cv2.imread(newpath)
    img=cv2.resize(img,(IMG_WIDTH,IMG_HEIGHT))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    X_test[n]=img
    n+=1

m=0
for name in tqdm(m1):
    newmaskpath = os.path.join(maskpath,name)
    mpg=cv2.imread(newmaskpath)
    mpg=cv2.resize(mpg,(IMG_WIDTH,IMG_HEIGHT))
    mpg = cv2.cvtColor(mpg, cv2.COLOR_BGR2GRAY)
    ret, mpg = cv2.threshold(mpg, 120, 255, cv2.THRESH_BINARY)
    mpg=np.expand_dims(mpg,axis=-1)
    Y_test[m]=mpg/255
    m+=1
# Out:
# creating test data
# 100%|██████████| 1000/1000 [00:10<00:00, 97.80it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 315.03it/s]

# %%
np.unique(Y_test)
# Out:
# array([0., 1.])

# %%
#Sanity check, view few mages
import random
import numpy as np
image_number = random.randint(0, len(X_test))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(X_test[image_number])
plt.subplot(122)
plt.imshow(array_to_img(Y_test[image_number]), cmap='gray')
plt.show()

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from sklearn.metrics import f1_score

# %%
def fscore(tp,Images,Masks):
    total=0
    i=0
    fs=0
    for i in range(len(Images)):
        total += 1
        
        tp[i][tp[i]>0.5]=1
        tp[i][tp[i]<0.5]=0

        pred = img_to_array(tp[i]).astype(int)
        label = img_to_array(np.squeeze(Masks[i], axis=2)).astype(int)
        flat_pred = np.ravel(pred)
        flat_label = np.ravel(label)

        fs += f1_score(flat_label,flat_pred, average='micro')

    fs=fs/total

    return fs

# %% [markdown]
# ## 150 epochs

# %% [markdown]
# IoU socre is:  0.8420013857669354
#
# F SCORE : 0.9802611035156239

# %%
model.load_weights("/content/drive/MyDrive/FY_HGS/AEC_EE_LINKNET_mobilenetv2/SAM_ASPP/0-150_callback/cp.ckpt")

# %%
y_pred=model.predict(X_test)

# %%
f=fscore(y_pred,X_test,Y_test)
print(f)
# Out:
# 0.9802611035156239

# %%
## Jaccard Index ( IoU )

#y_pred=model.predict(X_test)
y_pred_thresholded = y_pred > 0.5

intersection = np.logical_and(Y_test, y_pred_thresholded)
union = np.logical_or(Y_test, y_pred_thresholded)
iou_score = np.sum(intersection) / np.sum(union)
print("IoU socre is: ", iou_score)
# Out:
# IoU socre is:  0.8420013857669354

# %%
#Prediction test
import random
import numpy as np
image_number = random.randint(0, len(X_test))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(X_test[image_number])
plt.subplot(122)
plt.imshow(array_to_img(y_pred[image_number]), cmap='gray')
plt.show()

# %% [markdown]
# #SAVE THE MODEL

# %%
model.save("")
