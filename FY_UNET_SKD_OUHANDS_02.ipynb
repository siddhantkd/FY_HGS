# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhantkd/FY_HGS/blob/main/FY_UNET_SKD_OUHANDS_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 01 S Dutta Model OUHANDS
#
# >Retraining of S Dutta Model on OUHANDS
# >> > 01 S Dutta Model with Parameter changes - Batch Size = 16
# >> 32 dont work
#
# NEXT STEPS
#
# > 01 S Dutta Model on Libras

# %% [markdown]
# #IMPORT AND DRIVE LOAD

# %%
import cv2
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import keras
from tqdm import tqdm
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
# !nvidia-smi
# Out:
# Fri Dec 17 12:03:31 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8    29W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %% [markdown]
# #Data Loading

# %%
# !unzip '/content/drive/MyDrive/OUHANDS/OUHANDS_Siddhant.zip'

# %%
IMG_WIDTH = 320
IMG_HEIGHT = 320
IMG_CHANNELS = 3

# %%
path = "/content/OUHANDS_Siddhant/training/colour"
maskpath = "/content/OUHANDS_Siddhant/training/segmentation"

X_train = np.zeros((len(os.listdir(path)), IMG_HEIGHT, IMG_WIDTH,IMG_CHANNELS),dtype=np.uint8)
Y_train = np.zeros((len(os.listdir(maskpath)), IMG_HEIGHT, IMG_WIDTH,1))
print('creating input data')
n=0
for name in tqdm(os.listdir(path)):
    newpath = os.path.join(path,name)
    img=cv2.imread(newpath)
    img=cv2.resize(img,(IMG_WIDTH,IMG_HEIGHT))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    X_train[n]=img
    n+=1

m=0
for name in tqdm(os.listdir(maskpath)):
    newmaskpath = os.path.join(maskpath,name)
    mpg=cv2.imread(newmaskpath,0)
    mpg=cv2.resize(mpg,(IMG_WIDTH,IMG_HEIGHT))
    mpg=np.expand_dims(mpg,axis=-1)
    Y_train[m]=mpg/255
    m+=1
# Out:
# creating input data
# 100%|██████████| 2000/2000 [00:22<00:00, 88.34it/s]
# 100%|██████████| 2000/2000 [00:03<00:00, 567.47it/s]

# %%
plt.imshow(array_to_img(X_train[0]))

# %%
plt.imshow(array_to_img(Y_train[0]))

# %% [markdown]
# # UNET MODEL

# %%
X_train.shape
# Out:
# (2000, 320, 320, 3)

# %%
def UNETmod():
  #Build the model
  inputs = tf.keras.layers.Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
  s = tf.keras.layers.Lambda(lambda x: x / 255)(inputs)

  #Contraction path

  c1 = tf.keras.layers.Conv2D(16, (3, 3), kernel_initializer='he_normal', padding='same')(s)
  c1 = tf.keras.layers.BatchNormalization()(c1)
  c1 = tf.keras.layers.ReLU()(c1)
  c1 = tf.keras.layers.Conv2D(32, (3, 3), kernel_initializer='he_normal', padding='same')(c1)
  c1 = tf.keras.layers.BatchNormalization()(c1)
  c1 = tf.keras.layers.ReLU()(c1)
  c1 = tf.keras.layers.Dropout(0.1)(c1)
  c1 = tf.keras.layers.Conv2D(16, (3, 3), kernel_initializer='he_normal', padding='same')(c1)
  c1 = tf.keras.layers.BatchNormalization()(c1)
  c1 = tf.keras.layers.ReLU()(c1)
  p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

  c2 = tf.keras.layers.Conv2D(32, (3, 3), kernel_initializer='he_normal', padding='same')(p1)
  c2 = tf.keras.layers.BatchNormalization()(c2)
  c2 = tf.keras.layers.ReLU()(c2)
  c2 = tf.keras.layers.Conv2D(64, (3, 3), kernel_initializer='he_normal', padding='same')(c2)
  c2 = tf.keras.layers.BatchNormalization()(c2)
  c2 = tf.keras.layers.ReLU()(c2)
  c2 = tf.keras.layers.Dropout(0.1)(c2)
  c2 = tf.keras.layers.Conv2D(32, (3, 3), kernel_initializer='he_normal', padding='same')(c2)
  c2 = tf.keras.layers.BatchNormalization()(c2)
  c2 = tf.keras.layers.ReLU()(c2)
  p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)

  c3 = tf.keras.layers.Conv2D(64, (3, 3), kernel_initializer='he_normal', padding='same')(p2)
  c3 = tf.keras.layers.BatchNormalization()(c3)
  c3 = tf.keras.layers.ReLU()(c3)
  c3 = tf.keras.layers.Conv2D(128, (3, 3), kernel_initializer='he_normal', padding='same')(c3)
  c3 = tf.keras.layers.BatchNormalization()(c3)
  c3 = tf.keras.layers.ReLU()(c3)
  c3 = tf.keras.layers.Dropout(0.2)(c3)
  c3 = tf.keras.layers.Conv2D(64, (3, 3), kernel_initializer='he_normal', padding='same')(c3)
  c3 = tf.keras.layers.BatchNormalization()(c3)
  c3 = tf.keras.layers.ReLU()(c3)
  p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)

  c4 = tf.keras.layers.Conv2D(128, (3, 3), kernel_initializer='he_normal', padding='same')(p3)
  c4 = tf.keras.layers.BatchNormalization()(c4)
  c4 = tf.keras.layers.ReLU()(c4)
  c4 = tf.keras.layers.Conv2D(256, (3, 3), kernel_initializer='he_normal', padding='same')(c4)
  c4 = tf.keras.layers.BatchNormalization()(c4)
  c4 = tf.keras.layers.ReLU()(c4)
  c4 = tf.keras.layers.Dropout(0.2)(c4)
  c4 = tf.keras.layers.Conv2D(128, (3, 3), kernel_initializer='he_normal', padding='same')(c4)
  c4 = tf.keras.layers.BatchNormalization()(c4)
  c4 = tf.keras.layers.ReLU()(c4)
  p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)

  c5 = tf.keras.layers.Conv2D(256, (3, 3), kernel_initializer='he_normal', padding='same')(p4)
  c5 = tf.keras.layers.BatchNormalization()(c5)
  c5 = tf.keras.layers.ReLU()(c5)
  c5 = tf.keras.layers.Conv2D(512, (3, 3), kernel_initializer='he_normal', padding='same')(c5)
  c5 = tf.keras.layers.BatchNormalization()(c5)
  c5 = tf.keras.layers.ReLU()(c5)
  c5 = tf.keras.layers.Dropout(0.3)(c5)
  c5 = tf.keras.layers.Conv2D(256, (3, 3), kernel_initializer='he_normal', padding='same')(c5)
  c5 = tf.keras.layers.BatchNormalization()(c5)
  c5 = tf.keras.layers.ReLU()(c5)

  #Expansive path 
  u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
  u6 = tf.keras.layers.concatenate([u6, c4])
  c6 = tf.keras.layers.Conv2D(128, (3, 3), kernel_initializer='he_normal', padding='same')(u6)
  c6 = tf.keras.layers.BatchNormalization()(c6)
  c6 = tf.keras.layers.ReLU()(c6)
  c6 = tf.keras.layers.Conv2D(256, (3, 3), kernel_initializer='he_normal', padding='same')(c6)
  c6 = tf.keras.layers.BatchNormalization()(c6)
  c6 = tf.keras.layers.ReLU()(c6)
  c6 = tf.keras.layers.Dropout(0.2)(c6)
  c6 = tf.keras.layers.Conv2D(128, (3, 3), kernel_initializer='he_normal', padding='same')(c6)
  c6 = tf.keras.layers.BatchNormalization()(c6)
  c6 = tf.keras.layers.ReLU()(c6)
  
  u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
  u7 = tf.keras.layers.concatenate([u7, c3])
  c7 = tf.keras.layers.Conv2D(64, (3, 3), kernel_initializer='he_normal', padding='same')(u7)
  c7 = tf.keras.layers.BatchNormalization()(c7)
  c7 = tf.keras.layers.ReLU()(c7)
  c7 = tf.keras.layers.Conv2D(128, (3, 3), kernel_initializer='he_normal', padding='same')(c7)
  c7 = tf.keras.layers.BatchNormalization()(c7)
  c7 = tf.keras.layers.ReLU()(c7)
  c7 = tf.keras.layers.Dropout(0.2)(c7)
  c7 = tf.keras.layers.Conv2D(64, (3, 3), kernel_initializer='he_normal', padding='same')(c7)
  c7 = tf.keras.layers.BatchNormalization()(c7)
  c7 = tf.keras.layers.ReLU()(c7)
  
  u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
  u8 = tf.keras.layers.concatenate([u8, c2])
  c8 = tf.keras.layers.Conv2D(32, (3, 3), kernel_initializer='he_normal', padding='same')(u8)
  c8 = tf.keras.layers.BatchNormalization()(c8)
  c8 = tf.keras.layers.ReLU()(c8)
  c8 = tf.keras.layers.Conv2D(64, (3, 3), kernel_initializer='he_normal', padding='same')(c8)
  c8 = tf.keras.layers.BatchNormalization()(c8)
  c8 = tf.keras.layers.ReLU()(c8)
  c8 = tf.keras.layers.Dropout(0.1)(c8)
  c8 = tf.keras.layers.Conv2D(32, (3, 3), kernel_initializer='he_normal', padding='same')(c8)
  c8 = tf.keras.layers.BatchNormalization()(c8)
  c8 = tf.keras.layers.ReLU()(c8)
  
  u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
  u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
  c9 = tf.keras.layers.Conv2D(16, (3, 3), kernel_initializer='he_normal', padding='same')(u9)
  c9 = tf.keras.layers.BatchNormalization()(c9)
  c9 = tf.keras.layers.ReLU()(c9)
  c9 = tf.keras.layers.Conv2D(32, (3, 3), kernel_initializer='he_normal', padding='same')(c9)
  c9 = tf.keras.layers.BatchNormalization()(c9)
  c9 = tf.keras.layers.ReLU()(c9)
  c9 = tf.keras.layers.Dropout(0.1)(c9)
  c9 = tf.keras.layers.Conv2D(16, (3, 3), kernel_initializer='he_normal', padding='same')(c9)
  c9 = tf.keras.layers.BatchNormalization()(c9)
  c9 = tf.keras.layers.ReLU()(c9)
  
  outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)
  
  model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
  return model

# %%
model=UNETmod()

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 320, 320, 3  0           []
#                                 )]
#
#  lambda (Lambda)                (None, 320, 320, 3)  0           ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 320, 320, 16  448         ['lambda[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 320, 320, 16  64         ['conv2d[0][0]']
#  alization)                     )
#
#  re_lu (ReLU)                   (None, 320, 320, 16  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 320, 320, 32  4640        ['re_lu[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 320, 320, 32  128        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  re_lu_1 (ReLU)                 (None, 320, 320, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 320, 320, 32  0           ['re_lu_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 320, 320, 16  4624        ['dropout[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 320, 320, 16  64         ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  re_lu_2 (ReLU)                 (None, 320, 320, 16  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 160, 160, 16  0           ['re_lu_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 160, 160, 32  4640        ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 160, 160, 32  128        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  re_lu_3 (ReLU)                 (None, 160, 160, 32  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 160, 160, 64  18496       ['re_lu_3[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 160, 160, 64  256        ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  re_lu_4 (ReLU)                 (None, 160, 160, 64  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  dropout_1 (Dropout)            (None, 160, 160, 64  0           ['re_lu_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 160, 160, 32  18464       ['dropout_1[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 160, 160, 32  128        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  re_lu_5 (ReLU)                 (None, 160, 160, 32  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 80, 80, 32)  0           ['re_lu_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 80, 80, 64)   18496       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 80, 80, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  re_lu_6 (ReLU)                 (None, 80, 80, 64)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 80, 80, 128)  73856       ['re_lu_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 80, 80, 128)  512        ['conv2d_7[0][0]']
#  rmalization)
#
#  re_lu_7 (ReLU)                 (None, 80, 80, 128)  0           ['batch_normalization_7[0][0]']
#
#  dropout_2 (Dropout)            (None, 80, 80, 128)  0           ['re_lu_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 80, 80, 64)   73792       ['dropout_2[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 80, 80, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  re_lu_8 (ReLU)                 (None, 80, 80, 64)   0           ['batch_normalization_8[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 40, 40, 64)  0           ['re_lu_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 40, 40, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 40, 40, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  re_lu_9 (ReLU)                 (None, 40, 40, 128)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 40, 40, 256)  295168      ['re_lu_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 40, 40, 256)  1024       ['conv2d_10[0][0]']
#  ormalization)
#
#  re_lu_10 (ReLU)                (None, 40, 40, 256)  0           ['batch_normalization_10[0][0]']
#
#  dropout_3 (Dropout)            (None, 40, 40, 256)  0           ['re_lu_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 40, 40, 128)  295040      ['dropout_3[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 40, 40, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  re_lu_11 (ReLU)                (None, 40, 40, 128)  0           ['batch_normalization_11[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 20, 20, 128)  0          ['re_lu_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 20, 20, 256)  295168      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 20, 20, 256)  1024       ['conv2d_12[0][0]']
#  ormalization)
#
#  re_lu_12 (ReLU)                (None, 20, 20, 256)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 20, 20, 512)  1180160     ['re_lu_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 20, 20, 512)  2048       ['conv2d_13[0][0]']
#  ormalization)
#
#  re_lu_13 (ReLU)                (None, 20, 20, 512)  0           ['batch_normalization_13[0][0]']
#
#  dropout_4 (Dropout)            (None, 20, 20, 512)  0           ['re_lu_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 20, 20, 256)  1179904     ['dropout_4[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 20, 20, 256)  1024       ['conv2d_14[0][0]']
#  ormalization)
#
#  re_lu_14 (ReLU)                (None, 20, 20, 256)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 40, 40, 128)  131200     ['re_lu_14[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 40, 40, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   're_lu_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 40, 40, 128)  295040      ['concatenate[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 40, 40, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  re_lu_15 (ReLU)                (None, 40, 40, 128)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 40, 40, 256)  295168      ['re_lu_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 40, 40, 256)  1024       ['conv2d_16[0][0]']
#  ormalization)
#
#  re_lu_16 (ReLU)                (None, 40, 40, 256)  0           ['batch_normalization_16[0][0]']
#
#  dropout_5 (Dropout)            (None, 40, 40, 256)  0           ['re_lu_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 40, 40, 128)  295040      ['dropout_5[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 40, 40, 128)  512        ['conv2d_17[0][0]']
#  ormalization)
#
#  re_lu_17 (ReLU)                (None, 40, 40, 128)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 80, 80, 64)  32832       ['re_lu_17[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 80, 80, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   're_lu_8[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 80, 80, 64)   73792       ['concatenate_1[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 80, 80, 64)  256         ['conv2d_18[0][0]']
#  ormalization)
#
#  re_lu_18 (ReLU)                (None, 80, 80, 64)   0           ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 80, 80, 128)  73856       ['re_lu_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 80, 80, 128)  512        ['conv2d_19[0][0]']
#  ormalization)
#
#  re_lu_19 (ReLU)                (None, 80, 80, 128)  0           ['batch_normalization_19[0][0]']
#
#  dropout_6 (Dropout)            (None, 80, 80, 128)  0           ['re_lu_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 80, 80, 64)   73792       ['dropout_6[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 80, 80, 64)  256         ['conv2d_20[0][0]']
#  ormalization)
#
#  re_lu_20 (ReLU)                (None, 80, 80, 64)   0           ['batch_normalization_20[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 160, 160, 32  8224       ['re_lu_20[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 160, 160, 64  0           ['conv2d_transpose_2[0][0]',
#                                 )                                 're_lu_5[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 160, 160, 32  18464       ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_21 (BatchN  (None, 160, 160, 32  128        ['conv2d_21[0][0]']
#  ormalization)                  )
#
#  re_lu_21 (ReLU)                (None, 160, 160, 32  0           ['batch_normalization_21[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 160, 160, 64  18496       ['re_lu_21[0][0]']
#                                 )
#
#  batch_normalization_22 (BatchN  (None, 160, 160, 64  256        ['conv2d_22[0][0]']
#  ormalization)                  )
#
#  re_lu_22 (ReLU)                (None, 160, 160, 64  0           ['batch_normalization_22[0][0]']
#                                 )
#
#  dropout_7 (Dropout)            (None, 160, 160, 64  0           ['re_lu_22[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 160, 160, 32  18464       ['dropout_7[0][0]']
#                                 )
#
#  batch_normalization_23 (BatchN  (None, 160, 160, 32  128        ['conv2d_23[0][0]']
#  ormalization)                  )
#
#  re_lu_23 (ReLU)                (None, 160, 160, 32  0           ['batch_normalization_23[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 320, 320, 16  2064       ['re_lu_23[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 320, 320, 32  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 're_lu_2[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 320, 320, 16  4624        ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_24 (BatchN  (None, 320, 320, 16  64         ['conv2d_24[0][0]']
#  ormalization)                  )
#
#  re_lu_24 (ReLU)                (None, 320, 320, 16  0           ['batch_normalization_24[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 320, 320, 32  4640        ['re_lu_24[0][0]']
#                                 )
#
#  batch_normalization_25 (BatchN  (None, 320, 320, 32  128        ['conv2d_25[0][0]']
#  ormalization)                  )
#
#  re_lu_25 (ReLU)                (None, 320, 320, 32  0           ['batch_normalization_25[0][0]']
#                                 )
#
#  dropout_8 (Dropout)            (None, 320, 320, 32  0           ['re_lu_25[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 320, 320, 16  4624        ['dropout_8[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 320, 320, 16  64         ['conv2d_26[0][0]']
#  ormalization)                  )
#
#  re_lu_26 (ReLU)                (None, 320, 320, 16  0           ['batch_normalization_26[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 320, 320, 1)  17          ['re_lu_26[0][0]']
#
# ==================================================================================================
# Total params: 4,898,865
# Trainable params: 4,892,977
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %%
#Our CNN model
from keras.utils.vis_utils import plot_model
tf.keras.utils.plot_model(
    model, show_shapes=False, show_layer_names=True,
    rankdir='TB', expand_nested=False, dpi=96
)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # MODEL TRAINING

# %% [markdown]
# ##20 epochs

# %%
#Model Checkpoint
checkpoint_path_segmentUNET = "/content/drive/MyDrive/FY_HGS/SD_UNET_OUHANDS_02/cp.ckpt"
model_checkpoint_segmentUNET = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path_segmentUNET,
                                                 save_weights_only=True,
                                                  monitor='val_accuracy',save_best_only=True,
                                                 verbose=1)

# %%
history = model.fit(X_train,Y_train,validation_split = 0.1,batch_size=16,epochs=20,callbacks=[model_checkpoint_segmentUNET])
# Out:
# Epoch 1/20
# 113/113 [==============================] - ETA: 0s - loss: 0.3821 - accuracy: 0.9015
# Epoch 00001: val_accuracy improved from -inf to 0.76787, saving model to /content/drive/MyDrive/FY_HGS/SD_UNET_OUHANDS_02/cp.ckpt
# 113/113 [==============================] - 125s 1s/step - loss: 0.3821 - accuracy: 0.9015 - val_loss: 0.5464 - val_accuracy: 0.7679
# Epoch 2/20
# 113/113 [==============================] - ETA: 0s - loss: 0.1917 - accuracy: 0.9623
# Epoch 00002: val_accuracy did not improve from 0.76787
# 113/113 [==============================] - 114s 1s/step - loss: 0.1917 - accuracy: 0.9623 - val_loss: 1.8429 - val_accuracy: 0.7045
# Epoch 3/20
# 113/113 [==============================] - ETA: 0s - loss: 0.1102 - accuracy: 0.9750
# Epoch 00003: val_accuracy improved from 0.76787 to 0.86876, saving model to /content/drive/MyDrive/FY_HGS/SD_UNET_OUHANDS_02/cp.ckpt
# 113/113 [==============================] - 114s 1s/step - loss: 0.1102 - accuracy: 0.9750 - val_loss: 0.5091 - val_accuracy: 0.8688
# Epoch 4/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0775 - accuracy: 0.9789
# Epoch 00004: val_accuracy improved from 0.86876 to 0.97525, saving model to /content/drive/MyDrive/FY_HGS/SD_UNET_OUHANDS_02/cp.ckpt
# 113/113 [==============================] - 114s 1s/step - loss: 0.0775 - accuracy: 0.9789 - val_loss: 0.0874 - val_accuracy: 0.9753
# Epoch 5/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0637 - accuracy: 0.9795
# Epoch 00005: val_accuracy did not improve from 0.97525
# 113/113 [==============================] - 114s 1s/step - loss: 0.0637 - accuracy: 0.9795 - val_loss: 0.1607 - val_accuracy: 0.9481
# Epoch 6/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0496 - accuracy: 0.9826
# Epoch 00006: val_accuracy improved from 0.97525 to 0.98049, saving model to /content/drive/MyDrive/FY_HGS/SD_UNET_OUHANDS_02/cp.ckpt
# 113/113 [==============================] - 115s 1s/step - loss: 0.0496 - accuracy: 0.9826 - val_loss: 0.0531 - val_accuracy: 0.9805
# Epoch 7/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0441 - accuracy: 0.9834
# Epoch 00007: val_accuracy improved from 0.98049 to 0.98070, saving model to /content/drive/MyDrive/FY_HGS/SD_UNET_OUHANDS_02/cp.ckpt
# 113/113 [==============================] - 114s 1s/step - loss: 0.0441 - accuracy: 0.9834 - val_loss: 0.0537 - val_accuracy: 0.9807
# Epoch 8/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0432 - accuracy: 0.9827
# Epoch 00008: val_accuracy did not improve from 0.98070
# 113/113 [==============================] - 114s 1s/step - loss: 0.0432 - accuracy: 0.9827 - val_loss: 0.0513 - val_accuracy: 0.9791
# Epoch 9/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0464 - accuracy: 0.9809
# Epoch 00009: val_accuracy improved from 0.98070 to 0.98194, saving model to /content/drive/MyDrive/FY_HGS/SD_UNET_OUHANDS_02/cp.ckpt
# 113/113 [==============================] - 115s 1s/step - loss: 0.0464 - accuracy: 0.9809 - val_loss: 0.0452 - val_accuracy: 0.9819
# Epoch 10/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0360 - accuracy: 0.9846
# Epoch 00010: val_accuracy improved from 0.98194 to 0.98379, saving model to /content/drive/MyDrive/FY_HGS/SD_UNET_OUHANDS_02/cp.ckpt
# 113/113 [==============================] - 114s 1s/step - loss: 0.0360 - accuracy: 0.9846 - val_loss: 0.0371 - val_accuracy: 0.9838
# Epoch 11/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9849
# Epoch 00011: val_accuracy did not improve from 0.98379
# 113/113 [==============================] - 114s 1s/step - loss: 0.0346 - accuracy: 0.9849 - val_loss: 0.0379 - val_accuracy: 0.9833
# Epoch 12/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 0.9852
# Epoch 00012: val_accuracy did not improve from 0.98379
# 113/113 [==============================] - 114s 1s/step - loss: 0.0331 - accuracy: 0.9852 - val_loss: 0.0418 - val_accuracy: 0.9823
# Epoch 13/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0343 - accuracy: 0.9846
# Epoch 00013: val_accuracy did not improve from 0.98379
# 113/113 [==============================] - 114s 1s/step - loss: 0.0343 - accuracy: 0.9846 - val_loss: 0.0375 - val_accuracy: 0.9829
# Epoch 14/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0324 - accuracy: 0.9852
# Epoch 00014: val_accuracy improved from 0.98379 to 0.98416, saving model to /content/drive/MyDrive/FY_HGS/SD_UNET_OUHANDS_02/cp.ckpt
# 113/113 [==============================] - 114s 1s/step - loss: 0.0324 - accuracy: 0.9852 - val_loss: 0.0340 - val_accuracy: 0.9842
# Epoch 15/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0305 - accuracy: 0.9858
# Epoch 00015: val_accuracy improved from 0.98416 to 0.98471, saving model to /content/drive/MyDrive/FY_HGS/SD_UNET_OUHANDS_02/cp.ckpt
# 113/113 [==============================] - 115s 1s/step - loss: 0.0305 - accuracy: 0.9858 - val_loss: 0.0333 - val_accuracy: 0.9847
# Epoch 16/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0329 - accuracy: 0.9848
# Epoch 00016: val_accuracy did not improve from 0.98471
# 113/113 [==============================] - 114s 1s/step - loss: 0.0329 - accuracy: 0.9848 - val_loss: 0.0636 - val_accuracy: 0.9777
# Epoch 17/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0319 - accuracy: 0.9851
# Epoch 00017: val_accuracy did not improve from 0.98471
# 113/113 [==============================] - 114s 1s/step - loss: 0.0319 - accuracy: 0.9851 - val_loss: 0.0882 - val_accuracy: 0.9674
# Epoch 18/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0318 - accuracy: 0.9850
# Epoch 00018: val_accuracy did not improve from 0.98471
# 113/113 [==============================] - 114s 1s/step - loss: 0.0318 - accuracy: 0.9850 - val_loss: 0.0329 - val_accuracy: 0.9846
# Epoch 19/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0296 - accuracy: 0.9859
# Epoch 00019: val_accuracy improved from 0.98471 to 0.98509, saving model to /content/drive/MyDrive/FY_HGS/SD_UNET_OUHANDS_02/cp.ckpt
# 113/113 [==============================] - 116s 1s/step - loss: 0.0296 - accuracy: 0.9859 - val_loss: 0.0316 - val_accuracy: 0.9851
# Epoch 20/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0292 - accuracy: 0.9861
# Epoch 00020: val_accuracy did not improve from 0.98509
# 113/113 [==============================] - 114s 1s/step - loss: 0.0292 - accuracy: 0.9861 - val_loss: 0.0317 - val_accuracy: 0.9849

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.figure()
N = 20
plt.plot(np.arange(0,N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0,N), history.history["val_loss"], label = "val_loss")
plt.plot(np.arange(0,N), history.history["accuracy"], label = "train_acc")
plt.plot(np.arange(0,N), history.history["val_accuracy"], label = "val_acc")
plt.legend(loc="center right")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Training Error")
plt.savefig('UNET_Traininerrorplot_SEGMENTATION_RGB.png')

# %%
plt.plot(np.arange(0,N), history.history["val_loss"], label = "val_loss")
plt.title("Validation loss plot")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.savefig('UNET_ValLossPlot_SEGMENTATION_V1.2.png')

# %%
plt.plot(np.arange(0,N), history.history["loss"], label = "val_loss")
plt.title("Training loss plot")
plt.xlabel("Epoch")
plt.ylabel("Training Loss")
plt.savefig('UNET_TrainLossPlot_SEGMENTATION_V1.2.png')

# %% [markdown]
# ##40 Epochs

# %%
checkpoint_path_segmentUNET = "/content/drive/MyDrive/FY_HGS/SD_UNET_OUHANDS_02/cp.ckpt"
model.load_weights(checkpoint_path_segmentUNET)

# %%
checkpoint_path_segmentUNET = "/content/drive/MyDrive/FY_HGS/SD_UNET_OUHANDS_02/40ep/cp.ckpt"
model_checkpoint_segmentUNET = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path_segmentUNET,
                                                 save_weights_only=True,
                                                  monitor='val_accuracy',save_best_only=True,
                                                 verbose=1)

# %%
h2 =  model.fit(X_train,Y_train,validation_split = 0.1,batch_size=16,epochs=20,callbacks=[model_checkpoint_segmentUNET])
# Out:
# Epoch 1/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0288 - accuracy: 0.9862
# Epoch 00001: val_accuracy improved from -inf to 0.98520, saving model to /content/drive/MyDrive/FY_HGS/SD_UNET_OUHANDS_02/40ep/cp.ckpt
# 113/113 [==============================] - 118s 979ms/step - loss: 0.0288 - accuracy: 0.9862 - val_loss: 0.0317 - val_accuracy: 0.9852
# Epoch 2/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 0.9863
# Epoch 00002: val_accuracy did not improve from 0.98520
# 113/113 [==============================] - 111s 979ms/step - loss: 0.0286 - accuracy: 0.9863 - val_loss: 0.0330 - val_accuracy: 0.9846
# Epoch 3/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9857
# Epoch 00003: val_accuracy did not improve from 0.98520
# 113/113 [==============================] - 110s 974ms/step - loss: 0.0298 - accuracy: 0.9857 - val_loss: 0.0402 - val_accuracy: 0.9820
# Epoch 4/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0301 - accuracy: 0.9856
# Epoch 00004: val_accuracy did not improve from 0.98520
# 113/113 [==============================] - 111s 980ms/step - loss: 0.0301 - accuracy: 0.9856 - val_loss: 0.0330 - val_accuracy: 0.9847
# Epoch 5/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9862
# Epoch 00005: val_accuracy did not improve from 0.98520
# 113/113 [==============================] - 111s 986ms/step - loss: 0.0284 - accuracy: 0.9862 - val_loss: 0.0323 - val_accuracy: 0.9849
# Epoch 6/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0279 - accuracy: 0.9864
# Epoch 00006: val_accuracy did not improve from 0.98520
# 113/113 [==============================] - 111s 980ms/step - loss: 0.0279 - accuracy: 0.9864 - val_loss: 0.0333 - val_accuracy: 0.9844
# Epoch 7/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.9866
# Epoch 00007: val_accuracy did not improve from 0.98520
# 113/113 [==============================] - 111s 979ms/step - loss: 0.0274 - accuracy: 0.9866 - val_loss: 0.0328 - val_accuracy: 0.9851
# Epoch 8/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.9865
# Epoch 00008: val_accuracy improved from 0.98520 to 0.98546, saving model to /content/drive/MyDrive/FY_HGS/SD_UNET_OUHANDS_02/40ep/cp.ckpt
# 113/113 [==============================] - 111s 983ms/step - loss: 0.0275 - accuracy: 0.9865 - val_loss: 0.0304 - val_accuracy: 0.9855
# Epoch 9/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0272 - accuracy: 0.9866
# Epoch 00009: val_accuracy did not improve from 0.98546
# 113/113 [==============================] - 111s 980ms/step - loss: 0.0272 - accuracy: 0.9866 - val_loss: 0.0306 - val_accuracy: 0.9853
# Epoch 10/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0279 - accuracy: 0.9864
# Epoch 00010: val_accuracy did not improve from 0.98546
# 113/113 [==============================] - 111s 984ms/step - loss: 0.0279 - accuracy: 0.9864 - val_loss: 0.4398 - val_accuracy: 0.8487
# Epoch 11/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0394 - accuracy: 0.9823
# Epoch 00011: val_accuracy did not improve from 0.98546
# 113/113 [==============================] - 111s 980ms/step - loss: 0.0394 - accuracy: 0.9823 - val_loss: 0.0749 - val_accuracy: 0.9789
# Epoch 12/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0308 - accuracy: 0.9852
# Epoch 00012: val_accuracy did not improve from 0.98546
# 113/113 [==============================] - 111s 983ms/step - loss: 0.0308 - accuracy: 0.9852 - val_loss: 0.0307 - val_accuracy: 0.9852
# Epoch 13/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0280 - accuracy: 0.9863
# Epoch 00013: val_accuracy did not improve from 0.98546
# 113/113 [==============================] - 111s 983ms/step - loss: 0.0280 - accuracy: 0.9863 - val_loss: 0.0305 - val_accuracy: 0.9853
# Epoch 14/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0271 - accuracy: 0.9866
# Epoch 00014: val_accuracy did not improve from 0.98546
# 113/113 [==============================] - 111s 985ms/step - loss: 0.0271 - accuracy: 0.9866 - val_loss: 0.0312 - val_accuracy: 0.9850
# Epoch 15/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0271 - accuracy: 0.9866
# Epoch 00015: val_accuracy did not improve from 0.98546
# 113/113 [==============================] - 111s 982ms/step - loss: 0.0271 - accuracy: 0.9866 - val_loss: 0.0417 - val_accuracy: 0.9827
# Epoch 16/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9864
# Epoch 00016: val_accuracy did not improve from 0.98546
# 113/113 [==============================] - 111s 983ms/step - loss: 0.0277 - accuracy: 0.9864 - val_loss: 0.0306 - val_accuracy: 0.9853
# Epoch 17/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9869
# Epoch 00017: val_accuracy did not improve from 0.98546
# 113/113 [==============================] - 111s 982ms/step - loss: 0.0264 - accuracy: 0.9869 - val_loss: 0.0303 - val_accuracy: 0.9854
# Epoch 18/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9869
# Epoch 00018: val_accuracy improved from 0.98546 to 0.98547, saving model to /content/drive/MyDrive/FY_HGS/SD_UNET_OUHANDS_02/40ep/cp.ckpt
# 113/113 [==============================] - 111s 985ms/step - loss: 0.0262 - accuracy: 0.9869 - val_loss: 0.0302 - val_accuracy: 0.9855
# Epoch 19/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0259 - accuracy: 0.9870
# Epoch 00019: val_accuracy did not improve from 0.98547
# 113/113 [==============================] - 111s 984ms/step - loss: 0.0259 - accuracy: 0.9870 - val_loss: 0.0304 - val_accuracy: 0.9854
# Epoch 20/20
# 113/113 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.9870
# Epoch 00020: val_accuracy did not improve from 0.98547
# 113/113 [==============================] - 111s 980ms/step - loss: 0.0260 - accuracy: 0.9870 - val_loss: 0.0320 - val_accuracy: 0.9849

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.figure()
N = 20
plt.plot(np.arange(0,N), h2.history["loss"], label="train_loss")
plt.plot(np.arange(0,N), h2.history["val_loss"], label = "val_loss")
plt.plot(np.arange(0,N), h2.history["accuracy"], label = "train_acc")
plt.plot(np.arange(0,N), h2.history["val_accuracy"], label = "val_acc")
plt.legend(loc="center right")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Training Error")
plt.savefig('UNET_Traininerrorplot_SEGMENTATION_RGB.png')

# %%
plt.plot(np.arange(0,N), h2.history["val_loss"], label = "val_loss")
plt.title("Validation loss plot")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.savefig('UNET_ValLossPlot_SEGMENTATION_V1.2.png')

# %%
plt.plot(np.arange(0,N), h2.history["loss"], label = "val_loss")
plt.title("Training loss plot")
plt.xlabel("Epoch")
plt.ylabel("Training Loss")
plt.savefig('UNET_TrainLossPlot_SEGMENTATION_V1.2.png')

# %% [markdown]
# # **EVALUATION**

# %%
path = "/content/OUHANDS_Siddhant/testing/colour"
maskpath = "/content/OUHANDS_Siddhant/testing/segmentation"
p1 = os.listdir(path)
p1.sort()

m1 = os.listdir(maskpath)
m1.sort()

X_test = np.zeros((len(os.listdir(path)), IMG_HEIGHT, IMG_WIDTH,IMG_CHANNELS),dtype=np.uint8)
Y_test = np.zeros((len(os.listdir(maskpath)), IMG_HEIGHT, IMG_WIDTH,1))
print('creating test data')
n=0
for name in tqdm(p1):
    newpath = os.path.join(path,name)
    img=cv2.imread(newpath)
    img=cv2.resize(img,(IMG_WIDTH,IMG_HEIGHT))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    X_test[n]=img
    n+=1

m=0
for name in tqdm(m1):
    newmaskpath = os.path.join(maskpath,name)
    mpg=cv2.imread(newmaskpath,0)
    mpg=cv2.resize(mpg,(IMG_WIDTH,IMG_HEIGHT))
    mpg=np.expand_dims(mpg,axis=-1)
    Y_test[m]=mpg/255
    m+=1
# Out:
# creating test data
# 100%|██████████| 1000/1000 [00:10<00:00, 92.74it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 618.40it/s]

# %%
plt.imshow(X_test[0])

# %%
plt.imshow(array_to_img(Y_test[0]))

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from sklearn.metrics import f1_score

# %%
def fscore(tp,Images,Masks):
    total=0
    i=0
    fs=0
    for i in range(len(Images)):
        total += 1
        
        tp[i][tp[i]>0.5]=1
        tp[i][tp[i]<0.5]=0

        pred = img_to_array(tp[i]).astype(int)
        label = img_to_array(np.squeeze(Masks[i], axis=2)).astype(int)
        flat_pred = np.ravel(pred)
        flat_label = np.ravel(label)

        fs += f1_score(flat_label,flat_pred, average='micro')

    fs=fs/total

    return fs

# %% [markdown]
# #20 epochs

# %%
 #    ######evaluate#####
checkpoint_path_segmentUNET = "/content/drive/MyDrive/FY_HGS/SD_UNET_OUHANDS_02/cp.ckpt"
model.load_weights(checkpoint_path_segmentUNET)

# %%
y_pred=model.predict(X_test)

# %%
f=fscore(y_pred,X_test,Y_test)
print(f)
# Out:
# 0.9715895410156242

# %% [markdown]
# >S_UNET_01 ( batch size 8, epoch = 20 )
# >>F - 0.9523831738281249
#
# >>IOU - IoU socre is:  0.6868150559446907
#
# >S_UNET_02 ( batch size 16, epoch = 20 )
# >>F - 0.9715895703124994
#
#
# >>IOU - IoU socre is:  0.7748379419194803

# %%
## Jaccard Index ( IoU )

#y_pred=model.predict(X_test)
y_pred_thresholded = y_pred > 0.5

intersection = np.logical_and(Y_test, y_pred_thresholded)
union = np.logical_or(Y_test, y_pred_thresholded)
iou_score = np.sum(intersection) / np.sum(union)
print("IoU socre is: ", iou_score)
# Out:
# IoU socre is:  0.7748376792213415

# %%
checkpoint_path_segmentUNET = ""
model.load_weights(checkpoint_path_segmentUNET)
y_pred=model.predict(X_test)
f=fscore(y_pred,X_test,Y_test)
print(f)
# Out:
# 0.9739844335937484

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(X_test[0]))
#plt.title('TEST IMAGE')

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(Y_test[50]), cmap = 'gray')
#plt.title('TEST SEGMENTATION MASK GROUND TRUTH', fontsize=8)

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(y_pred[50]), cmap = 'gray')
#plt.title('TEST SEGMENTATION MASK OBTAINED FROM DEEP LEARNING MODULE', fontsize=8)

# %%
x_test_single = np.expand_dims(X_test[10], axis = 0)

# %%
import time
start_time = time.time()
y_single = model.predict(x_test_single)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.8144223690032959 seconds ---

# %% [markdown]
# ## CUSTOM 20 ep

# %%
# !unzip '/content/drive/MyDrive/IMG_PNG.zip'
# Out:
# Archive:  /content/drive/MyDrive/IMG_PNG.zip
#    creating: IMG_PNG/
#   inflating: IMG_PNG/IMG_0332.png
#   inflating: IMG_PNG/IMG_0333.png
#   inflating: IMG_PNG/IMG_0334.png
#   inflating: IMG_PNG/IMG_0335.png

# %%
path = "/content/IMG_PNG"
p1 = os.listdir(path)

X_test_custom = np.zeros((len(os.listdir(path)), IMG_HEIGHT, IMG_WIDTH,IMG_CHANNELS),dtype=np.uint8)
print('creating test data')
n=0
for name in tqdm(p1):
    newpath = os.path.join(path,name)
    img=cv2.imread(newpath)
    img=cv2.resize(img,(IMG_WIDTH,IMG_HEIGHT))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    X_test_custom[n]=img
    n+=1
# Out:
# creating test data
# 100%|██████████| 4/4 [00:01<00:00,  3.46it/s]

# %%
y_pred_custom=model.predict(X_test_custom)

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(X_test_custom[0]))
plt.title('TEST IMAGE')
# Out:
# Text(0.5, 1.0, 'TEST IMAGE')

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(y_pred_custom[0]), cmap = 'gray')
plt.title('TEST SEGMENTATION MASK OBTAINED FROM DEEP LEARNING MODULE', fontsize=8)
# Out:
# Text(0.5, 1.0, 'TEST SEGMENTATION MASK OBTAINED FROM DEEP LEARNING MODULE')

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(X_test_custom[1]))
plt.title('TEST IMAGE')
# Out:
# Text(0.5, 1.0, 'TEST IMAGE')

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(y_pred_custom[1]), cmap = 'gray')
plt.title('TEST SEGMENTATION MASK OBTAINED FROM DEEP LEARNING MODULE', fontsize=8)
# Out:
# Text(0.5, 1.0, 'TEST SEGMENTATION MASK OBTAINED FROM DEEP LEARNING MODULE')

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(X_test_custom[2]))
plt.title('TEST IMAGE')
# Out:
# Text(0.5, 1.0, 'TEST IMAGE')

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(y_pred_custom[2]), cmap = 'gray')
plt.title('TEST SEGMENTATION MASK OBTAINED FROM DEEP LEARNING MODULE', fontsize=8)
# Out:
# Text(0.5, 1.0, 'TEST SEGMENTATION MASK OBTAINED FROM DEEP LEARNING MODULE')

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(X_test_custom[3]))
plt.title('TEST IMAGE')
# Out:
# Text(0.5, 1.0, 'TEST IMAGE')

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(y_pred_custom[3]), cmap = 'gray')
plt.title('TEST SEGMENTATION MASK OBTAINED FROM DEEP LEARNING MODULE', fontsize=8)
# Out:
# Text(0.5, 1.0, 'TEST SEGMENTATION MASK OBTAINED FROM DEEP LEARNING MODULE')

# %% [markdown]
# #40Epochs

# %%
 #    ######evaluate#####
checkpoint_path_segmentUNET = "/content/drive/MyDrive/FY_HGS/SD_UNET_OUHANDS_02/40ep/cp.ckpt"
model.load_weights(checkpoint_path_segmentUNET)

# %%
y_pred=model.predict(X_test)

# %%
f=fscore(y_pred,X_test,Y_test)
print(f)
# Out:
# 0.9663742968749999

# %% [markdown]
# >S_UNET_01 ( batch size 8, epoch = 20 )
# >>F - 0.960910859375
#
# >>IOU - IoU socre is:  0.726285815651112
#
# >S_UNET_02 ( batch size 16, epoch = 20 )
# >>F - 0.9663742968749999
#
#
# >>IOU - IoU socre is: 0.7408842047000074

# %%
## Jaccard Index ( IoU )

#y_pred=model.predict(X_test)
y_pred_thresholded = y_pred > 0.5

intersection = np.logical_and(Y_test, y_pred_thresholded)
union = np.logical_or(Y_test, y_pred_thresholded)
iou_score = np.sum(intersection) / np.sum(union)
print("IoU socre is: ", iou_score)
# Out:
# IoU socre is:  0.7408842047000074

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(X_test[50]))
#plt.title('TEST IMAGE')

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(Y_test[50]), cmap = 'gray')
#plt.title('TEST SEGMENTATION MASK GROUND TRUTH', fontsize=8)

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(y_pred[50]), cmap = 'gray')
#plt.title('TEST SEGMENTATION MASK OBTAINED FROM DEEP LEARNING MODULE', fontsize=8)

# %%
import time
x_test_single = np.expand_dims(X_test[8], axis = 0)

start_time = time.time()
y_single = model.predict(x_test_single)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.08934760093688965 seconds ---

# %% [markdown]
# ### Custom

# %%
y_pred_custom=model.predict(X_test_custom)

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(X_test_custom[0]))
plt.title('TEST IMAGE')
# Out:
# Text(0.5, 1.0, 'TEST IMAGE')

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(y_pred_custom[0]), cmap = 'gray')
plt.title('TEST SEGMENTATION MASK OBTAINED FROM DEEP LEARNING MODULE', fontsize=8)
# Out:
# Text(0.5, 1.0, 'TEST SEGMENTATION MASK OBTAINED FROM DEEP LEARNING MODULE')

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(X_test_custom[1]))
plt.title('TEST IMAGE')
# Out:
# Text(0.5, 1.0, 'TEST IMAGE')

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(y_pred_custom[1]), cmap = 'gray')
plt.title('TEST SEGMENTATION MASK OBTAINED FROM DEEP LEARNING MODULE', fontsize=8)
# Out:
# Text(0.5, 1.0, 'TEST SEGMENTATION MASK OBTAINED FROM DEEP LEARNING MODULE')

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(X_test_custom[2]))
plt.title('TEST IMAGE')
# Out:
# Text(0.5, 1.0, 'TEST IMAGE')

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(y_pred_custom[2]), cmap = 'gray')
plt.title('TEST SEGMENTATION MASK OBTAINED FROM DEEP LEARNING MODULE', fontsize=8)
# Out:
# Text(0.5, 1.0, 'TEST SEGMENTATION MASK OBTAINED FROM DEEP LEARNING MODULE')

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(X_test_custom[3]))
plt.title('TEST IMAGE')
# Out:
# Text(0.5, 1.0, 'TEST IMAGE')

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(array_to_img(y_pred_custom[3]), cmap = 'gray')
plt.title('TEST SEGMENTATION MASK OBTAINED FROM DEEP LEARNING MODULE', fontsize=8)
# Out:
# Text(0.5, 1.0, 'TEST SEGMENTATION MASK OBTAINED FROM DEEP LEARNING MODULE')

# %% [markdown]
# #SAVE THE MODEL

# %%
model.save("")
